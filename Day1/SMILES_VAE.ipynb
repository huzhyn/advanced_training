# %% [markdown]
# # ENV

# %%
# %%bash
# MINICONDA_INSTALLER_SCRIPT=Miniconda3-4.5.4-Linux-x86_64.sh
# MINICONDA_PREFIX=/usr/local
# wget https://repo.continuum.io/miniconda/$MINICONDA_INSTALLER_SCRIPT
# chmod +x $MINICONDA_INSTALLER_SCRIPT
# ./$MINICONDA_INSTALLER_SCRIPT -b -f -p $MINICONDA_PREFIX
# conda install --channel defaults conda python=3.6 --yes
# conda update --channel defaults --all --yes
# Out:
# PREFIX=/usr/local
# installing: python-3.6.5-hc3d631a_2 ...
# installing: ca-certificates-2018.03.07-0 ...
# installing: conda-env-2.6.0-h36134e3_1 ...
# installing: libgcc-ng-7.2.0-hdf63c60_3 ...
# installing: libstdcxx-ng-7.2.0-hdf63c60_3 ...
# installing: libffi-3.2.1-hd88cf55_4 ...
# installing: ncurses-6.1-hf484d3e_0 ...
# installing: openssl-1.0.2o-h20670df_0 ...
# installing: tk-8.6.7-hc745277_3 ...
# installing: xz-5.2.4-h14c3975_4 ...
# installing: yaml-0.1.7-had09818_2 ...
# installing: zlib-1.2.11-ha838bed_2 ...
# installing: libedit-3.1.20170329-h6b74fdf_2 ...
# installing: readline-7.0-ha6073c6_4 ...
# installing: sqlite-3.23.1-he433501_0 ...
# installing: asn1crypto-0.24.0-py36_0 ...
# installing: certifi-2018.4.16-py36_0 ...
# installing: chardet-3.0.4-py36h0f667ec_1 ...
# installing: idna-2.6-py36h82fb2a8_1 ...
# installing: pycosat-0.6.3-py36h0a5515d_0 ...
# installing: pycparser-2.18-py36hf9f622e_1 ...
# installing: pysocks-1.6.8-py36_0 ...
# installing: ruamel_yaml-0.15.37-py36h14c3975_2 ...
# installing: six-1.11.0-py36h372c433_1 ...
# installing: cffi-1.11.5-py36h9745a5d_0 ...
# installing: setuptools-39.2.0-py36_0 ...
# installing: cryptography-2.2.2-py36h14c3975_0 ...
# installing: wheel-0.31.1-py36_0 ...
# installing: pip-10.0.1-py36_0 ...
# installing: pyopenssl-18.0.0-py36_0 ...
# installing: urllib3-1.22-py36hbe7ace6_0 ...
# installing: requests-2.18.4-py36he2e5f8d_1 ...
# installing: conda-4.5.4-py36_0 ...
# installation finished.
# WARNING:
#     You currently have a PYTHONPATH environment variable set. This may cause
#     unexpected behavior when running the Python interpreter in Miniconda3.
#     For best results, please verify that your PYTHONPATH only points to
#     directories of packages that are compatible with the Python interpreter
#     in Miniconda3: /usr/local
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: /usr/local
#
#   added / updated specs:
#     - conda
#     - python=3.6
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     cryptography-3.1.1         |   py36h1ba5d50_0         612 KB
#     xz-5.2.5                   |       h7b6447c_0         438 KB
#     cffi-1.14.3                |   py36he30daa8_0         224 KB
#     _libgcc_mutex-0.1          |             main           3 KB
#     libffi-3.3                 |       he6710b0_2          54 KB
#     libgcc-ng-9.1.0            |       hdf63c60_0         8.1 MB
#     ca-certificates-2020.10.14 |                0         128 KB
#     brotlipy-0.7.0             |py36h7b6447c_1000         348 KB
#     ld_impl_linux-64-2.33.1    |       h53a641e_7         645 KB
#     pyopenssl-19.1.0           |             py_1          47 KB
#     sqlite-3.33.0              |       h62c20be_0         2.0 MB
#     pycosat-0.6.3              |   py36h7b6447c_0         107 KB
#     certifi-2020.6.20          |     pyhd3eb1b0_3         159 KB
#     tk-8.6.10                  |       hbc83047_0         3.2 MB
#     urllib3-1.25.11            |             py_0          93 KB
#     zlib-1.2.11                |       h7b6447c_3         120 KB
#     tqdm-4.50.2                |             py_0          55 KB
#     libedit-3.1.20191231       |       h14c3975_1         121 KB
#     libstdcxx-ng-9.1.0         |       hdf63c60_0         4.0 MB
#     requests-2.24.0            |             py_0          54 KB
#     readline-8.0               |       h7b6447c_0         428 KB
#     conda-package-handling-1.7.2|   py36h03888b9_0         967 KB
#     conda-4.9.1                |   py36h06a4308_0         3.1 MB
#     yaml-0.2.5                 |       h7b6447c_0          87 KB
#     openssl-1.1.1h             |       h7b6447c_0         3.8 MB
#     pip-20.2.4                 |   py36h06a4308_0         2.1 MB
#     python-3.6.12              |       hcff3b4d_2        34.0 MB
#     wheel-0.35.1               |             py_0          36 KB
#     six-1.15.0                 |             py_0          13 KB
#     ruamel_yaml-0.15.87        |   py36h7b6447c_1         256 KB
#     pycparser-2.20             |             py_2          94 KB
#     setuptools-50.3.1          |   py36h06a4308_1         900 KB
#     ncurses-6.2                |       he6710b0_1         1.1 MB
#     chardet-3.0.4              |        py36_1003         197 KB
#     pysocks-1.7.1              |           py36_0          30 KB
#     idna-2.10                  |             py_0          56 KB
#     ------------------------------------------------------------
#                                            Total:        67.5 MB
#
# The following NEW packages will be INSTALLED:
#
#     _libgcc_mutex:          0.1-main
#     brotlipy:               0.7.0-py36h7b6447c_1000
#     conda-package-handling: 1.7.2-py36h03888b9_0
#     ld_impl_linux-64:       2.33.1-h53a641e_7
#     tqdm:                   4.50.2-py_0
#
# The following packages will be UPDATED:
#
#     ca-certificates:        2018.03.07-0            --> 2020.10.14-0
#     certifi:                2018.4.16-py36_0        --> 2020.6.20-pyhd3eb1b0_3
#     cffi:                   1.11.5-py36h9745a5d_0   --> 1.14.3-py36he30daa8_0
#     chardet:                3.0.4-py36h0f667ec_1    --> 3.0.4-py36_1003
#     conda:                  4.5.4-py36_0            --> 4.9.1-py36h06a4308_0
#     cryptography:           2.2.2-py36h14c3975_0    --> 3.1.1-py36h1ba5d50_0
#     idna:                   2.6-py36h82fb2a8_1      --> 2.10-py_0
#     libedit:                3.1.20170329-h6b74fdf_2 --> 3.1.20191231-h14c3975_1
#     libffi:                 3.2.1-hd88cf55_4        --> 3.3-he6710b0_2
#     libgcc-ng:              7.2.0-hdf63c60_3        --> 9.1.0-hdf63c60_0
#     libstdcxx-ng:           7.2.0-hdf63c60_3        --> 9.1.0-hdf63c60_0
#     ncurses:                6.1-hf484d3e_0          --> 6.2-he6710b0_1
#     openssl:                1.0.2o-h20670df_0       --> 1.1.1h-h7b6447c_0
#     pip:                    10.0.1-py36_0           --> 20.2.4-py36h06a4308_0
#     pycosat:                0.6.3-py36h0a5515d_0    --> 0.6.3-py36h7b6447c_0
#     pycparser:              2.18-py36hf9f622e_1     --> 2.20-py_2
#     pyopenssl:              18.0.0-py36_0           --> 19.1.0-py_1
#     pysocks:                1.6.8-py36_0            --> 1.7.1-py36_0
#     python:                 3.6.5-hc3d631a_2        --> 3.6.12-hcff3b4d_2
#     readline:               7.0-ha6073c6_4          --> 8.0-h7b6447c_0
#     requests:               2.18.4-py36he2e5f8d_1   --> 2.24.0-py_0
#     ruamel_yaml:            0.15.37-py36h14c3975_2  --> 0.15
MB/s) - ‘Miniconda3-4.5.4-Linux-x86_64.sh’ saved [58468498/58468498]
#
# Python 3.6.5 :: Anaconda, Inc.
# cryptography-3.1.1   |  612 KB | ########## | 100%
# xz-5.2.5             |  438 KB | ########## | 100%
# cffi-1.14.3          |  224 KB | ########## | 100%
# _libgcc_mutex-0.1    |    3 KB | ########## | 100%
# libffi-3.3           |   54 KB | ########## | 100%
# libgcc-ng-9.1.0      |  8.1 MB | ########## | 100%
# ca-certificates-2020 |  128 KB | ########## | 100%
# brotlipy-0.7.0       |  348 KB | ########## | 100%
# ld_impl_linux-64-2.3 |  645 KB | ########## | 100%
# pyopenssl-19.1.0     |   47 KB | ########## | 100%
# sqlite-3.33.0        |  2.0 MB | ########## | 100%
# pycosat-0.6.3        |  107 KB | ########## | 100%
# certifi-2020.6.20    |  159 KB | ########## | 100%
# tk-8.6.10            |  3.2 MB | ########## | 100%
# urllib3-1.25.11      |   93 KB | ########## | 100%
# zlib-1.2.11          |  120 KB | ########## | 100%
# tqdm-4.50.2          |   55 KB | ########## | 100%
# libedit-3.1.20191231 |  121 KB | ########## | 100%
# libstdcxx-ng-9.1.0   |  4.0 MB | ########## | 100%
# requests-2.24.0      |   54 KB | ########## | 100%
# readline-8.0         |  428 KB | ########## | 100%
# conda-package-handli |  967 KB | ########## | 100%
# conda-4.9.1          |  3.1 MB | ########## | 100%
# yaml-0.2.5           |   87 KB | ########## | 100%
# openssl-1.1.1h       |  3.8 MB | ########## | 100%
# pip-20.2.4           |  2.1 MB | ########## | 100%
# python-3.6.12        | 34.0 MB | ########## | 100%
# wheel-0.35.1         |   36 KB | ########## | 100%
# six-1.15.0           |   13 KB | ########## | 100%
# ruamel_yaml-0.15.87  |  256 KB | ########## | 100%
# pycparser-2.20       |   94 KB | ########## | 100%
# setuptools-50.3.1    |  900 KB | ########## | 100%
# ncurses-6.2          |  1.1 MB | ########## | 100%
# chardet-3.0.4        |  197 KB | ########## | 100%
# pysocks-1.7.1        |   30 KB | ########## | 100%
# idna-2.10            |   56 KB | ########## | 100%

# %%
# !conda install -c rdkit rdkit --yes
# Out:
# done
# done
#
# ## Package Plan ##
#
#   environment location: /usr/local
#
#   added / updated specs:
#     - rdkit
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     blas-1.0                   |              mkl           6 KB
#     bzip2-1.0.8                |       h7b6447c_0          78 KB
#     cairo-1.14.12              |       h8948797_3         906 KB
#     fontconfig-2.13.0          |       h9420a91_0         227 KB
#     freetype-2.10.4            |       h5ab3b9f_0         596 KB
#     glib-2.66.1                |       h92f7085_0         2.9 MB
#     icu-58.2                   |       he6710b0_3        10.5 MB
#     intel-openmp-2020.2        |              254         786 KB
#     jpeg-9b                    |       h024ee3a_2         214 KB
#     lcms2-2.11                 |       h396b838_0         307 KB
#     libboost-1.73.0            |      h37e3b65_11        13.9 MB
#     libpng-1.6.37              |       hbc83047_0         278 KB
#     libtiff-4.1.0              |       h2733197_1         449 KB
#     libuuid-1.0.3              |       h1bed415_2          15 KB
#     libxcb-1.14                |       h7b6447c_0         505 KB
#     libxml2-2.9.10             |       hb55368b_3         1.2 MB
#     lz4-c-1.9.2                |       heb0550a_3         175 KB
#     mkl-2020.2                 |              256       138.3 MB
#     mkl-service-2.3.0          |   py36he904b0f_0         219 KB
#     mkl_fft-1.2.0              |   py36h23d657b_0         149 KB
#     mkl_random-1.1.1           |   py36h0573a6f_0         327 KB
#     numpy-1.19.2               |   py36h54aff64_0          22 KB
#     numpy-base-1.19.2          |   py36hfa32c7d_0         4.1 MB
#     olefile-0.46               |           py36_0          48 KB
#     pandas-1.1.3               |   py36he6710b0_0         8.2 MB
#     pcre-8.44                  |       he6710b0_0         212 KB
#     pillow-8.0.1               |   py36he98fc37_0         621 KB
#     pixman-0.40.0              |       h7b6447c_0         370 KB
#     py-boost-1.73.0            |  py36h962f231_11         204 KB
#     python-dateutil-2.8.1      |             py_0         215 KB
#     pytz-2020.1                |             py_0         184 KB
#     rdkit-2020.09.1.0          |   py36hd50e099_1        26.0 MB  rdkit
#     zstd-1.4.5                 |       h9ceee32_0         619 KB
#     ------------------------------------------------------------
#                                            Total:       212.6 MB
#
# The following NEW packages will be INSTALLED:
#
#   blas               pkgs/main/linux-64::blas-1.0-mkl
#   bzip2              pkgs/main/linux-64::bzip2-1.0.8-h7b6447c_0
#   cairo              pkgs/main/linux-64::cairo-1.14.12-h8948797_3
#   fontconfig         pkgs/main/linux-64::fontconfig-2.13.0-h9420a91_0
#   freetype           pkgs/main/linux-64::freetype-2.10.4-h5ab3b9f_0
#   glib               pkgs/main/linux-64::glib-2.66.1-h92f7085_0
#   icu                pkgs/main/linux-64::icu-58.2-he6710b0_3
#   intel-openmp       pkgs/main/linux-64::intel-openmp-2020.2-254
#   jpeg               pkgs/main/linux-64::jpeg-9b-h024ee3a_2
#   lcms2              pkgs/main/linux-64::lcms2-2.11-h396b838_0
#   libboost           pkgs/main/linux-64::libboost-1.73.0-h37e3b65_11
#   libpng             pkgs/main/linux-64::libpng-1.6.37-hbc83047_0
#   libtiff            pkgs/main/linux-64::libtiff-4.1.0-h2733197_1
#   libuuid            pkgs/main/linux-64::libuuid-1.0.3-h1bed415_2
#   libxcb             pkgs/main/linux-64::libxcb-1.14-h7b6447c_0
#   libxml2            pkgs/main/linux-64::libxml2-2.9.10-hb55368b_3
#   lz4-c              pkgs/main/linux-64::lz4-c-1.9.2-heb0550a_3
#   mkl                pkgs/main/linux-64::mkl-2020.2-256
#   mkl-service        pkgs/main/linux-64::mkl-service-2.3.0-py36he904b0f_0
#   mkl_fft            pkgs/main/linux-64::mkl_fft-1.2.0-py36h23d657b_0
#   mkl_random         pkgs/main/linux-64::mkl_random-1.1.1-py36h0573a6f_0
#   numpy              pkgs/main/linux-64::numpy-1.19.2-py36h54aff64_0
#   numpy-base         pkgs/main/linux-64::numpy-base-1.19.2-py36hfa32c7d_0
#   olefile            pkgs/main/linux-64::olefile-0.46-py36_0
#   pandas             pkgs/main/linux-64::pandas-1.1.3-py36he6710b0_0
#   pcre               pkgs/main/linux-64::pcre-8.44-he6710b0_0
#   pillow             pkgs/main/linux-64::pillow-8.0.1-py36he98fc37_0
#   pixman             pkgs/main/linux-64::pixman-0.40.0-h7b6447c_0
#   py-boost           pkgs/main/linux-64::py-boost-1.73.0-py36h962f231_11
#   python-dateutil    pkgs/main/noarch::python-dateutil-2.8.1-py_0
#   pytz               pkgs/main/noarch::pytz-2020.1-py_0
#   rdkit              rdkit/linux-64::rdkit-2020.09.1.0-py36hd50e099_1
#   zstd               pkgs/main/linux-64::zstd-1.4.5-h9ceee32_0
#
#
#
# Downloading and Extracting Packages
# icu-58.2             | 10.5 MB   | : 100% 1.0/1 [00:00<00:00,  1.94it/s]
# jpeg-9b              | 214 KB    | : 100% 1.0/1 [00:00<00:00, 16.46it/s]
# python-dateutil-2.8. | 215 KB    | : 100% 1.0/1 [00:00<00:00, 17.11it/s]
# olefile-0.46         | 48 KB     | : 100% 1.0/1 [00:00<00:00, 23.95it/s]
# mkl-service-2.3.0    | 219 KB    | : 100% 1.0/1 [00:00<00:00, 15.99it/s]
# py-boost-1.73.0      | 204 KB    | : 100% 1.0/1 [00:00<00:00, 15.34it/s]
# pixman-0.40.0        | 370 KB    | : 100% 1.0/1 [00:00<00:00, 16.50it/s]
# libtiff-4.1.0        | 449 KB    | : 100% 1.0/1 [00:00<00:00, 16.48it/s]
# libboost-1.73.0      | 13.9 MB   | : 100% 1.0/1 [00:01<00:00,  1.95s/it]
# numpy-base-1.19.2    | 4.1 MB    | : 100% 1.0/1 [00:00<00:00,  3.70it/s]
# freetype-2.10.4      | 596 KB    | : 100% 1.0/1 [00:00<00:00, 14.47it/s]
# mkl-2020.2           | 138.3 MB  | : 100% 1.0/1 [00:04<00:00,  4.40s/it]
# lz4-c-1.9.2          | 175 KB    | : 100% 1.0/1 [00:00<00:00, 15.68it/s]
# glib-2.66.1          | 2.9 MB    | : 100% 1.0/1 [00:00<00:00,  5.19it/s]
# blas-1.0             | 6 KB      | : 100% 1.0/1 [00:00<00:00, 19.27it/s]
# pytz-2020.1          | 184 KB    | : 100% 1.0/1 [00:00<00:00, 10.04it/s]
# pcre-8.44            | 212 KB    | : 100% 1.0/1 [00:06<00:00,  6.26s/it]
# libxcb-1.14          | 505 KB    | : 100% 1.0/1 [00:00<00:00, 12.45it/s]
# libpng-1.6.37        | 278 KB    | : 100% 1.0/1 [00:00<00:00, 15.34it/s]
# zstd-1.4.5           | 619 KB    | : 100% 1.0/1 [00:00<00:00, 13.04it/s]
# cairo-1.14.12        | 906 KB    | : 100% 1.0/1 [00:00<00:00, 12.40it/s]
# numpy-1.19.2         | 22 KB     | : 100% 1.0/1 [00:00<00:00, 19.15it/s]
# mkl_random-1.1.1     | 327 KB    | : 100% 1.0/1 [00:00<00:00, 18.22it/s]
# rdkit-2020.09.1.0    | 26.0 MB   | : 100% 1.0/1 [00:04<00:00,  4.77s/it]
# bzip2-1.0.8          | 78 KB     | : 100% 1.0/1 [00:00<00:00, 17.65it/s]
# fontconfig-2.13.0    | 227 KB    | : 100% 1.0/1 [00:00<00:00, 16.29it/s]
# intel-openmp-2020.2  | 786 KB    | : 100% 1.0/1 [00:00<00:00, 15.63it/s]
# libuuid-1.0.3        | 15 KB     | : 100% 1.0/1 [00:00<00:00, 17.31it/s]
# pillow-8.0.1         | 621 KB    | : 100% 1.0/1 [00:00<00:00, 12.69it/s]
# mkl_fft-1.2.0        | 149 KB    | : 100% 1.0/1 [00:00<00:00, 19.02it/s]
# pandas-1.1.3         | 8.2 MB    | : 100% 1.0/1 [00:00<00:00,  2.37it/s]
# lcms2-2.11           | 307 KB    | : 100% 1.0/1 [00:00<00:00, 16.38it/s]
# libxml2-2.9.10       | 1.2 MB    | : 100% 1.0/1 [00:00<00:00, 10.42it/s]
# done
# done
# done

# %%
# add conda packages to path
import sys
sys.path.append("/usr/local/lib/python3.6/site-packages")

# %%
pip install molsets
# Out:
# Collecting molsets
#   Downloading molsets-0.3.1-py3-none-any.whl (51.6 MB)
#      |████████████████████████████████| 51.6 MB 27 kB/s
# Requirement already satisfied: numpy>=1.15 in /usr/local/lib/python3.6/site-packages (from molsets) (1.19.2)
# Collecting seaborn>=0.9.0
#   Downloading seaborn-0.11.0-py3-none-any.whl (283 kB)
#      |████████████████████████████████| 283 kB 65.5 MB/s
# Collecting scipy>=1.1.0
#   Downloading scipy-1.5.4-cp36-cp36m-manylinux1_x86_64.whl (25.9 MB)
#      |████████████████████████████████| 25.9 MB 36 kB/s
# Requirement already satisfied: tqdm>=4.26.0 in /usr/local/lib/python3.6/site-packages (from molsets) (4.50.2)
# Collecting torch>=1.1.0
#   Downloading torch-1.7.0-cp36-cp36m-manylinux1_x86_64.whl (776.7 MB)
#      |████████████████████████████████| 776.7 MB 812 bytes/s
# Collecting matplotlib>=3.0.0
#   Downloading matplotlib-3.3.2-cp36-cp36m-manylinux1_x86_64.whl (11.6 MB)
#      |████████████████████████████████| 11.6 MB 123 kB/s
# Collecting pomegranate==0.12.0
#   Downloading pomegranate-0.12.0-cp36-cp36m-manylinux1_x86_64.whl (5.6 MB)
#      |████████████████████████████████| 5.6 MB 56.8 MB/s
# Collecting fcd-torch>=1.0.5
#   Downloading fcd_torch-1.0.7-py3-none-any.whl (5.2 MB)
#      |████████████████████████████████| 5.2 MB 63.8 MB/s
# Requirement already satisfied: pandas>=0.25 in /usr/local/lib/python3.6/site-packages (from molsets) (1.1.3)
# Collecting future
#   Downloading future-0.18.2.tar.gz (829 kB)
#      |████████████████████████████████| 829 kB 57.0 MB/s
# Collecting typing-extensions
#   Downloading typing_extensions-3.7.4.3-py3-none-any.whl (22 kB)
# Collecting dataclasses
#   Downloading dataclasses-0.7-py3-none-any.whl (18 kB)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.6/site-packages (from matplotlib>=3.0.0->molsets) (8.0.1)
# Collecting kiwisolver>=1.0.1
#   Downloading kiwisolver-1.3.1-cp36-cp36m-manylinux1_x86_64.whl (1.1 MB)
#      |████████████████████████████████| 1.1 MB 55.8 MB/s
# Requirement already satisfied: python-dateutil>=2.1 in /usr/local/lib/python3.6/site-packages (from matplotlib>=3.0.0->molsets) (2.8.1)
# Requirement already satisfied: certifi>=2020.06.20 in /usr/local/lib/python3.6/site-packages (from matplotlib>=3.0.0->molsets) (2020.6.20)
# Collecting pyparsing!=2.0.4,!=2.1.2,!=2.1.6,>=2.0.3
#   Downloading pyparsing-2.4.7-py2.py3-none-any.whl (67 kB)
#      |████████████████████████████████| 67 kB 6.7 MB/s
# Collecting cycler>=0.10
#   Downloading cycler-0.10.0-py2.py3-none-any.whl (6.5 kB)
# Collecting networkx>=2.0
#   Downloading networkx-2.5-py3-none-any.whl (1.6 MB)
#      |████████████████████████████████| 1.6 MB 47.9 MB/s
# Collecting joblib>=0.9.0b4
#   Downloading joblib-0.17.0-py3-none-any.whl (301 kB)
#      |████████████████████████████████| 301 kB 72.8 MB/s
# Collecting pyyaml
#   Downloading PyYAML-5.3.1.tar.gz (269 kB)
#      |████████████████████████████████| 269 kB 74.4 MB/s
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.6/site-packages (from pandas>=0.25->molsets) (2020.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.6/site-packages (from python-dateutil>=2.1->matplotlib>=3.0.0->molsets) (1.15.0)
# Collecting decorator>=4.3.0
#   Downloading decorator-4.4.2-py2.py3-none-any.whl (9.2 kB)
# Building wheels for collected packages: future, pyyaml
#   Building wheel for future (setup.py) ... done
#   Created wheel for future: filename=future-0.18.2-py3-none-any.whl size=491059 sha256=e280fd85332ace3a0a470474cbec958440546f7269a936abcca27264ac1ae66b
#   Stored in directory: /root/.cache/pip/wheels/6e/9c/ed/4499c9865ac1002697793e0ae05ba6be33553d098f3347fb94
#   Building wheel for pyyaml (setup.py) ... done
#   Created wheel for pyyaml: filename=PyYAML-5.3.1-cp36-cp36m-linux_x86_64.whl size=402165 sha256=dc1db74b5496f4f2d6dead12bed999735919948a1838fda87ff410412f7bba71
#   Stored in directory: /root/.cache/pip/wheels/e5/9d/ad/2ee53cf262cba1ffd8afe1487eef788ea3f260b7e6232a80fc
# Successfully built future pyyaml
# Installing collected packages: scipy, kiwisolver, pyparsing, cycler, matplotlib, seaborn, future, typing-extensions, dataclasses, torch, decorator, networkx, joblib, pyyaml, pomegranate, fcd-torch, molsets
# Successfully installed cycler-0.10.0 dataclasses-0.7 decorator-4.4.2 fcd-torch-1.0.7 future-0.18.2 joblib-0.17.0 kiwisolver-1.3.1 matplotlib-3.3.2 molsets-0.3.1 networkx-2.5 pomegranate-0.12.0 pyparsing-2.4.7 pyyaml-5.3.1 scipy-1.5.4 seaborn-0.11.0 torch-1.7.0 typing-extensions-3.7.4.3

# %% [markdown]
# # Smiles VAE

# %%
import moses
from moses.utils import OneHotVocab

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
tds = moses.get_dataset('train')
vds = moses.get_dataset('test')
len(tds), len(vds)
# Out:
# (1584663, 176074)

# %%
vocab = OneHotVocab.from_data(tds)
vocab

# %%
from argparse import Namespace

# %%
old_config1 = Namespace(**{
    
 'clip_grad': 50,
 'd_cell': 'gru',
 'd_d_h': 512,
 'd_dropout': 0,
 'd_n_layers': 3,
 'd_z': 128,
 'freeze_embeddings': False,
 'kl_start': 0,
 'kl_w_end': 0.05,
 'kl_w_start': 0,
 'log_file': './log_file',
 'lr_end': 0.00030000000000000003,
 'lr_n_mult': 1,
 'lr_n_period': 10,
 'lr_n_restarts': 1,
 'lr_start': 0.00030000000000000003,
 'n_batch': 512,
 'n_jobs': 1,
 'n_last': 1000,
 'n_workers': 1,
 'q_bidir': False,
 'q_cell': 'gru',
 'q_d_h': 256,
 'q_dropout': 0.5,
 'q_n_layers': 1,

 'model': 'all',
 'test_path': None,
 'test_scaffolds_path': None,
 'train_path': None,
 'ptest_path': None,
 'ptest_scaffolds_path': None,
 'checkpoint_dir': './checkpoints',
 'n_samples': 30000,
 'n_jobs': 1,
 'device': 'cpu',
 'metrics': 'metrics.csv',
 'train_size': None,
 'test_size': None,
 'experiment_suff': ''
 })

# %%
# !wget https://www.dropbox.com/s/e8wvuojcyr7rvna/save_vae.zip
# !unzip save_vae.zip
# Out:
# --2020-11-08 22:26:31--  https://www.dropbox.com/s/e8wvuojcyr7rvna/save_vae.zip
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.1.1, 2620:100:6016:1::a27d:101
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.1.1|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: /s/raw/e8wvuojcyr7rvna/save_vae.zip [following]
# --2020-11-08 22:26:31--  https://www.dropbox.com/s/raw/e8wvuojcyr7rvna/save_vae.zip
# Reusing existing connection to www.dropbox.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://uc1a62f0de991a9781e5c9b2d68d.dl.dropboxusercontent.com/cd/0/inline/BC0H_tBvt2cjyUnx6kTvqbiyfw0RFSqWNcvFGeICqzUUXky3sFnFSL9O6jATfPS0FIfrp6ifDxW9fArpLEG92vF7Q03D66xWPUlzhk0atSVIunSMZLRdRSJJjYZRPMCbZWQ/file# [following]
# --2020-11-08 22:26:31--  https://uc1a62f0de991a9781e5c9b2d68d.dl.dropboxusercontent.com/cd/0/inline/BC0H_tBvt2cjyUnx6kTvqbiyfw0RFSqWNcvFGeICqzUUXky3sFnFSL9O6jATfPS0FIfrp6ifDxW9fArpLEG92vF7Q03D66xWPUlzhk0atSVIunSMZLRdRSJJjYZRPMCbZWQ/file
# Resolving uc1a62f0de991a9781e5c9b2d68d.dl.dropboxusercontent.com (uc1a62f0de991a9781e5c9b2d68d.dl.dropboxusercontent.com)... 162.125.1.15, 2620:100:6016:15::a27d:10f
# Connecting to uc1a62f0de991a9781e5c9b2d68d.dl.dropboxusercontent.com (uc1a62f0de991a9781e5c9b2d68d.dl.dropboxusercontent.com)|162.125.1.15|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: /cd/0/inline2/
#   inflating: __MACOSX/save_aae/._.DS_Store
#   inflating: save_aae/aae_config.pt
#   inflating: __MACOSX/save_aae/._aae_config.pt
#   inflating: save_aae/aae_log.txt
#   inflating: __MACOSX/save_aae/._aae_log.txt
#   inflating: save_aae/aae_model_060.pt
#   inflating: __MACOSX/save_aae/._aae_model_060.pt
#   inflating: save_aae/aae_model_100.pt
#   inflating: __MACOSX/save_aae/._aae_model_100.pt
#   inflating: save_aae/aae_model_040.pt
#   inflating: __MACOSX/save_aae/._aae_model_040.pt
#   inflating: save_aae/aae_model_000.pt
#   inflating: __MACOSX/save_aae/._aae_model_000.pt
#   inflating: save_aae/aae_model_020.pt
#   inflating: __MACOSX/save_aae/._aae_model_020.pt
#   inflating: save_aae/aae_model.pt
#   inflating: __MACOSX/save_aae/._aae_model.pt
#   inflating: save_aae/aae_model_080.pt
#   inflating: __MACOSX/save_aae/._aae_model_080.pt

# %%
import torch
old_config2 = torch.load("/content/drive/My Drive/save_model/save_vae/vae_config.pt")
old_config2
# Out:
# Namespace(clip_grad=50, config_save='./checkpoints/vae_config.pt', d_cell='gru', d_d_h=512, d_dropout=0, d_n_layers=3, d_z=128, device='cuda', freeze_embeddings=False, kl_start=0, kl_w_end=0.05, kl_w_start=0, log_file='./checkpoints/vae_log.txt', lr_end=0.00030000000000000003, lr_n_mult=1, lr_n_period=10, lr_n_restarts=10, lr_start=0.00030000000000000003, model_save='./checkpoints/vae_model.pt', n_batch=512, n_jobs=1, n_last=1000, n_workers=1, q_bidir=False, q_cell='gru', q_d_h=256, q_dropout=0.5, q_n_layers=1, save_frequency=20, seed=0, train_load=None, val_load=None, vocab_load=None, vocab_save='./checkpoints/vae_vocab.pt')

# %%
old1 = vars(old_config1)
old2 = vars(old_config2)
config = old1.update(old2)
config =  Namespace(**old1)
config
# Out:
# Namespace(checkpoint_dir='./checkpoints', clip_grad=50, config_save='./checkpoints/vae_config.pt', d_cell='gru', d_d_h=512, d_dropout=0, d_n_layers=3, d_z=128, device='cuda', experiment_suff='', freeze_embeddings=False, kl_start=0, kl_w_end=0.05, kl_w_start=0, log_file='./checkpoints/vae_log.txt', lr_end=0.00030000000000000003, lr_n_mult=1, lr_n_period=10, lr_n_restarts=10, lr_start=0.00030000000000000003, metrics='metrics.csv', model='all', model_save='./checkpoints/vae_model.pt', n_batch=512, n_jobs=1, n_last=1000, n_samples=30000, n_workers=1, ptest_path=None, ptest_scaffolds_path=None, q_bidir=False, q_cell='gru', q_d_h=256, q_dropout=0.5, q_n_layers=1, save_frequency=20, seed=0, test_path=None, test_scaffolds_path=None, test_size=None, train_load=None, train_path=None, train_size=None, val_load=None, vocab_load=None, vocab_save='./checkpoints/vae_vocab.pt')

# %%
import moses.vae
vae = moses.vae.VAE(vocab = vocab, config=config)
vae
# Out:
# VAE(
#   (x_emb): Embedding(30, 30, padding_idx=28)
#   (encoder_rnn): GRU(30, 256, batch_first=True)
#   (q_mu): Linear(in_features=256, out_features=128, bias=True)
#   (q_logvar): Linear(in_features=256, out_features=128, bias=True)
#   (decoder_rnn): GRU(158, 512, num_layers=3, batch_first=True)
#   (decoder_lat): Linear(in_features=128, out_features=512, bias=True)
#   (decoder_fc): Linear(in_features=512, out_features=30, bias=True)
#   (encoder): ModuleList(
#     (0): GRU(30, 256, batch_first=True)
#     (1): Linear(in_features=256, out_features=128, bias=True)
#     (2): Linear(in_features=256, out_features=128, bias=True)
#   )
#   (decoder): ModuleList(
#     (0): GRU(158, 512, num_layers=3, batch_first=True)
#     (1): Linear(in_features=128, out_features=512, bias=True)
#     (2): Linear(in_features=512, out_features=30, bias=True)
#   )
#   (vae): ModuleList(
#     (0): Embedding(30, 30, padding_idx=28)
#     (1): ModuleList(
#       (0): GRU(30, 256, batch_first=True)
#       (1): Linear(in_features=256, out_features=128, bias=True)
#       (2): Linear(in_features=256, out_features=128, bias=True)
#     )
#     (2): ModuleList(
#       (0): GRU(158, 512, num_layers=3, batch_first=True)
#       (1): Linear(in_features=128, out_features=512, bias=True)
#       (2): Linear(in_features=512, out_features=30, bias=True)
#     )
#   )
# )

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
class AttrPredictor(nn.Module):
  """
  Receives latent vector z, predicts LogP, SA, and QED.
  """
  
  def __init__(self, d_z):
    super().__init__()
    self.predictors = nn.ModuleDict(
        {k: nn.Sequential(
            nn.Linear(d_z, d_z),
            nn.ReLU(),
            nn.Linear(d_z, 1)) 
        for k in ['logp', 'sa', 'qed']})
  
  def forward(self, z):
    return [self.predictors[k](z) for k in ['logp', 'sa', 'qed']]

# %%
ap = AttrPredictor(128)

# %%
saved_model = torch.load("/content/drive/My Drive/save_model/save_vae/vae_model.pt")

# %%
for p, v in vae.named_parameters():
  print(p, v.shape, saved_model[p].shape)
vae.load_state_dict(saved_model)
# Out:
# x_emb.weight torch.Size([30, 30]) torch.Size([30, 30])
# encoder_rnn.weight_ih_l0 torch.Size([768, 30]) torch.Size([768, 30])
# encoder_rnn.weight_hh_l0 torch.Size([768, 256]) torch.Size([768, 256])
# encoder_rnn.bias_ih_l0 torch.Size([768]) torch.Size([768])
# encoder_rnn.bias_hh_l0 torch.Size([768]) torch.Size([768])
# q_mu.weight torch.Size([128, 256]) torch.Size([128, 256])
# q_mu.bias torch.Size([128]) torch.Size([128])
# q_logvar.weight torch.Size([128, 256]) torch.Size([128, 256])
# q_logvar.bias torch.Size([128]) torch.Size([128])
# decoder_rnn.weight_ih_l0 torch.Size([1536, 158]) torch.Size([1536, 158])
# decoder_rnn.weight_hh_l0 torch.Size([1536, 512]) torch.Size([1536, 512])
# decoder_rnn.bias_ih_l0 torch.Size([1536]) torch.Size([1536])
# decoder_rnn.bias_hh_l0 torch.Size([1536]) torch.Size([1536])
# decoder_rnn.weight_ih_l1 torch.Size([1536, 512]) torch.Size([1536, 512])
# decoder_rnn.weight_hh_l1 torch.Size([1536, 512]) torch.Size([1536, 512])
# decoder_rnn.bias_ih_l1 torch.Size([1536]) torch.Size([1536])
# decoder_rnn.bias_hh_l1 torch.Size([1536]) torch.Size([1536])
# decoder_rnn.weight_ih_l2 torch.Size([1536, 512]) torch.Size([1536, 512])
# decoder_rnn.weight_hh_l2 torch.Size([1536, 512]) torch.Size([1536, 512])
# decoder_rnn.bias_ih_l2 torch.Size([1536]) torch.Size([1536])
# decoder_rnn.bias_hh_l2 torch.Size([1536]) torch.Size([1536])
# decoder_lat.weight torch.Size([512, 128]) torch.Size([512, 128])
# decoder_lat.bias torch.Size([512]) torch.Size([512])
# decoder_fc.weight torch.Size([30, 512]) torch.Size([30, 512])
# decoder_fc.bias torch.Size([30]) torch.Size([30])
# <All keys matched successfully>

# %%
from moses.metrics.utils import logP, QED, SA
from rdkit import rdBase
from rdkit import Chem
from rdkit.Chem import rdMolDescriptors
from rdkit.six import iteritems
from rdkit.Chem import AllChem
from rdkit.Chem import MACCSkeys
from rdkit.Chem.AllChem import GetMorganFingerprintAsBitVect as Morgan
from rdkit.Chem.QED import qed
from rdkit.Chem.Scaffolds import MurckoScaffold
from rdkit.Chem import Descriptors

# %%
sampled = vae.sample(10)
# Out:
# /usr/local/lib/python3.6/site-packages/moses/vae/model.py:217: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead. (Triggered internally at  /pytorch/aten/src/ATen/native/IndexingUtils.h:25.)
#   x[~eos_mask, i] = w[~eos_mask]
# /usr/local/lib/python3.6/site-packages/moses/vae/model.py:219: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead. (Triggered internally at  /pytorch/aten/src/ATen/native/IndexingUtils.h:25.)
#   end_pads[i_eos_mask] = i + 1

# %%
for smiles in sampled:
  mol = Chem.MolFromSmiles(smiles)
  if mol is not None:
    logp = logP(mol)
    qd = QED(mol)
    sa = SA(mol)
    print(smiles, logp, qd, sa)
# Out:
# N#CCCN(CCC#N)C(=O)c1cnc(-c2ccccc2)nc1 2.4131600000000004 0.816530233183157 2.3617062065402674
# Cc1ccc(Cc2nnc(NC(=O)c3cc(C)on3)o2)cc1 2.5175400000000003 0.7949919390723886 2.264356324219724
# Cc1ccc(C(=O)OCc2cccc(S(=O)(=O)N(C)C)c2)s1 2.663820000000001 0.7857846845263669 2.10297028026368
# O=C(NCc1ccc(N2CCCC2=O)cc1)c1cccs1 2.804900000000001 0.9436414470370127 1.9207306317814759
# CC(C)COC1CCN(C(=O)c2cnc(C3CCCO3)s2)CC1 3.2718000000000016 0.8266768983172734 3.1606330536834033
# NC(=O)COc1cccc(COC(=O)c2cnc3ccccc3n2)c1 1.8508999999999998 0.68839264951573 2.056149313099718
# NC(=O)CCN(C(=O)COc1ccccc1)c1ccccc1 1.9739999999999995 0.8491181598058593 1.8214859945493949
# COc1ccc(F)c(NC(=O)CC(C)C)c1OC 2.8275000000000006 0.8796716794835826 2.0122904259919157
# CCCc1nnc(NC(=O)N(C)C(C)c2ccc(O)cc2)s1 3.421100000000002 0.8845322104409247 2.7876970460128003
# CCn1cc(C(=O)NCC(C)C)c(=O)c2cc(F)ccc21 2.5463000000000013 0.9404839949326654 2.0880994908775126

# %%
trainer = moses.vae.VAETrainer(config)
vae = vae.cuda()

# %%
vae = vae.cuda()
z= vae.sample_z_prior(10).detach().cpu()
out = vae.sample(10, z=z)
# Out:
# /usr/local/lib/python3.6/site-packages/moses/vae/model.py:217: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead. (Triggered internally at  /pytorch/aten/src/ATen/native/IndexingUtils.h:25.)
#   x[~eos_mask, i] = w[~eos_mask]
# /usr/local/lib/python3.6/site-packages/moses/vae/model.py:219: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead. (Triggered internally at  /pytorch/aten/src/ATen/native/IndexingUtils.h:25.)
#   end_pads[i_eos_mask] = i + 1

# %%
import seaborn as sns
sns.heatmap(z.detach().cpu())

# %%
out
# Out:
# ['Cc1[nH]nc(C(=O)NC(C)COc2ccccc2)c1N',
#  'COC(=O)C1=C(COC(=O)c2cc(C)[nH]n2)OC(C)(C)C1',
#  'Cc1cc(F)ccc1NC(=O)CCNC(=O)c1ccoc1',
#  'CCOc1cc(CN2CCOC(C#N)C2)ccc1OC',
#  'CCSc1ccc(NC(=O)c2csnn2)cn1',
#  'COc1cccc(-c2cc(C(=O)NCCN3CCOCC3)on2)c1',
#  'CNC(=O)c1nc(Cc2ccccc2OC)no1',
#  'O=C(NCCC1=CCCCC1)c1cc(F)c2[nH]cnc12',
#  'NC(=O)CSc1nnc(COn2cncn2)n1Cc1ccccc1',
#  'CN(C(=O)CCNC(=O)OCC(F)(F)F)c1ccccc1']

# %%
moses.get_all_metrics(out)
# Out:
# /usr/local/lib/python3.6/site-packages/moses/metrics/metrics.py:217: UserWarning: Can't compute unique@1000.gen contains only 9 molecules
#   "gen contains only {} molecules".format(len(gen))
# /usr/local/lib/python3.6/site-packages/moses/metrics/metrics.py:217: UserWarning: Can't compute unique@10000.gen contains only 9 molecules
#   "gen contains only {} molecules".format(len(gen))
# {'FCD/Test': 50.44231262018458,
#  'FCD/TestSF': 50.60173430512796,
#  'Filters': 1.0,
#  'Frag/Test': 0.8396673359082742,
#  'Frag/TestSF': 0.8373003079105568,
#  'IntDiv': 0.7428617006466712,
#  'IntDiv2': 0.6308330073195276,
#  'Novelty': 0.5555555555555556,
#  'QED': 0.033438232513883344,
#  'SA': 0.1147132009389381,
#  'SNN/Test': 0.6007152431541019,
#  'SNN/TestSF': 0.5861065089702606,
#  'Scaf/Test': 0.021387157268856538,
#  'Scaf/TestSF': 0.0,
#  'logP': 0.8449041150942855,
#  'unique@1000': 1.0,
#  'unique@10000': 1.0,
#  'valid': 0.9,
#  'weight': 15.180468448240841}

# %% [markdown]
# # Find and Make Data(at Property)

# %%
pip install mhfp
# Out:
# Collecting mhfp
#   Downloading mhfp-1.9.2-py3-none-any.whl (9.7 kB)
# Installing collected packages: mhfp
# Successfully installed mhfp-1.9.2

# %%
import pandas as pd
import mhfp
from mhfp.encoder import MHFPEncoder
from mhfp.lsh_forest import LSHForestHelper
from tqdm import tqdm
from joblib import Parallel, delayed, cpu_count

# %%
moses_base_smiles = moses.get_dataset('train')
moses_base_smiles[:50]
# Out:
# array(['CCCS(=O)c1ccc2[nH]c(=NC(=O)OC)[nH]c2c1',
#        'CC(C)(C)C(=O)C(Oc1ccc(Cl)cc1)n1ccnc1',
#        'Cc1c(Cl)cccc1Nc1ncccc1C(=O)OCC(O)CO',
#        'Cn1cnc2c1c(=O)n(CC(O)CO)c(=O)n2C',
#        'CC1Oc2ccc(Cl)cc2N(CC(O)CO)C1=O', 'CCOC(=O)c1cncn1C1CCCc2ccccc21',
#        'COc1ccccc1OC(=O)Oc1ccccc1OC',
#        'O=C1Nc2ccc(Cl)cc2C(c2ccccc2Cl)=NC1O',
#        'CN1C(=O)C(O)N=C(c2ccccc2Cl)c2cc(Cl)ccc21',
#        'CCC(=O)c1ccc(OCC(O)CO)c(OC)c1',
#        'Cc1nc2c([nH]1)c(=O)n(C)c(=O)n2CC1CC=CCC1',
#        'COc1cc2c(cc1O)N=CC1CCC(O)N1C2=O',
#        'COc1c(C)cnc(CS(=O)c2nc3ccccc3[nH]2)c1C',
#        'COc1cc(C)c(Cc2cnc(N)nc2N)cc1OC',
#        'O=C1Nc2ccc(Cl)cc2C(c2ccccc2)=NC1O',
#        'CC1CC(OC(=O)CN2CCCC2=O)CC(C)(C)C1',
#        'O=C(C1CCCCC1)N1CC(=O)N2CCc3ccccc3C2C1',
#        'COC(=O)c1c[nH]c2cc(OC(C)C)c(OC(C)C)cc2c1=O',
#        'CCC1NC(=O)c2cc(S(N)(=O)=O)c(Cl)cc2N1',
#        'CN1C(=O)C(O)N=C(c2ccccc2)c2cc(Cl)ccc21',
#        'CC(C)(C)C(=O)C(Oc1ccc(Cl)cc1)n1cncn1',
#        'COc1cc(C(=O)N2CCOCC2)cc(OC)c1OC',
#        'CC(c1ncncc1F)C(O)(Cn1cncn1)c1ccc(F)cc1F',
#        'COc1ccc(C=C2CCCN=C2c2cccnc2)c(OC)c1',
#        'CC(=O)Nc1ccc(S(=O)(=O)c2ccc(NC(C)=O)cc2)cc1',
#        'CC(=O)Oc1cc(C)c(OC(C)=O)c2ccccc12',
#        'CC(=O)Oc1cccc(OC(C)=O)c1OC(C)=O',
#        'CC1(C)C(=O)Nc2cc3nc(-c4ccncc4)[nH]c3cc21',
#        'CC(C)C=c1[nH]c(=O)c(=Cc2ccccc2)[nH]c1=O',
#        'NC(=O)Nc1ccc(S(=O)(=O)c2ccc(N)cc2)cc1',
#        'CC(C)(C#N)c1cc(Cn2cncn2)cc(C(C)(C)C#N)c1',
#        'CNC(=O)Oc1ccccc1C(=O)Nc1ccccc1',
#        'COc1ccc(-c2nnc(C)nc2-c2ccc(OC)cc2)cc1',
#        'Nc1ncnc2c1ncn2Cc1c(F)cccc1Cl',
#        'Clc1ccc(C2(Cn3cncn3)OCCO2)c(Cl)c1',
#        'Cc1cc(Cc2cnc(N)nc2N)c2cccnc2c1N(C)C',
#        'NS(=O)(=O)c1ccc(NCc2ccccc2)cc1',
#        'CC1(C)C=C(n2ccccc2=O)c2cc(C#N)ccc2O1',
#        'O=C1CN=C(c2ccccn2)c2cc(Br)ccc2N1',
#        'CN(CCO)c1nc2c(c(=O)n(C)c(=O)n2C)n1C',
#        'CCC1(O)C(=O)OCc2c1cc1n(c2=O)Cc2cc3ccccc3nc2-1',
#        'CN1C(=O)CC(=O)N(c2ccccc2)c2cc(Cl)ccc21',
#        'NS(=O)(=O)c1cc2c(cc1Cl)CN(C1CCCCC1)C2=O',
#        'CCc1cc2c(s1)N(C)C(=O)CN=C2c1ccccc1Cl',
#        'CC1(C)Oc2ccc(C#N)cc2C(N2CCCC2=O)C1O',
#        'Nc1nc2c(ncn2C2CC(CO)C2CO)c(=O)[nH]1',
#        'CC12CCC3=C(CCc4cc(O)ccc43)C1CCC2=O',
#        'CNC(=O)c1ccc(Cl)c(S(=O)(=O)NC)c1', 'NC(=O)c1cc(Br)cc(Br)c1O',
#        'O=C(c1ccccc1)c1cccc(NS(=O)(=O)C(F)F)c1'], dtype=object)

# %%
# !wget https://www.dropbox.com/s/1joqmcy815zidco/trials.current%2Bpatterns.pains.csv
# Out:
# --2020-11-09 00:13:15--  https://www.dropbox.com/s/1joqmcy815zidco/trials.current%2Bpatterns.pains.csv
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.1.1, 2620:100:6016:1::a27d:101
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.1.1|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: /s/raw/1joqmcy815zidco/trials.current%2Bpatterns.pains.csv [following]
# --2020-11-09 00:13:15--  https://www.dropbox.com/s/raw/1joqmcy815zidco/trials.current%2Bpatterns.pains.csv
# Reusing existing connection to www.dropbox.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://ucaec65e0c494e84892083789653.dl.dropboxusercontent.com/cd/0/inline/BC3nPksIUOWDiTUw6I-fPIUxtFRCH4oVaR-gMy84EG7gJY4-wnnL4PSo55ANG8XgKj8rfR4o8C2Yk6gQzyU7az5pPa_Xxg09UJ6D_kSZaLdesjeh3lyQ10DCJ28-QDKPsCw/file# [following]
# --2020-11-09 00:13:15--  https://ucaec65e0c494e84892083789653.dl.dropboxusercontent.com/cd/0/inline/BC3nPksIUOWDiTUw6I-fPIUxtFRCH4oVaR-gMy84EG7gJY4-wnnL4PSo55ANG8XgKj8rfR4o8C2Yk6gQzyU7az5pPa_Xxg09UJ6D_kSZaLdesjeh3lyQ10DCJ28-QDKPsCw/file
# Resolving ucaec65e0c494e84892083789653.dl.dropboxusercontent.com (ucaec65e0c494e84892083789653.dl.dropboxusercontent.com)... 162.125.1.15, 2620:100:6016:15::a27d:10f
# Connecting to ucaec65e0c494e84892083789653.dl.dropboxusercontent.com (ucaec65e0c494e84892083789653.dl.dropboxusercontent.com)|162.125.1.15|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 8300 (8.1K) [text/plain]
# Saving to: ‘trials.current+patterns.pains.csv’
#
# trials.current+patt 100%[===================>]   8.11K  --.-KB/s    in 0s
#
# 2020-11-09 00:13:16 (168 MB/s) - ‘trials.current+patterns.pains.csv’ saved [8300/8300]

# %%
moses_seed = pd.Series(moses_base_smiles)
pain_set = pd.read_csv("/trials.current+patterns.pains.csv")#, index_col=0)
pain_set
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-16-96f77840372a> in <module>()
#       1 #moses_seed = pd.Series(moses_base_smiles)
# ----> 2 pain_set = pd.read_csv("/trials.current+patterns.pains.csv")#, index_col=0)
#       3 pain_set
#
# NameError: name 'pd' is not defined

# %%
# %%time

def pmap(pickleable_fn, data, n_jobs=cpu_count() - 1, verbose=1, **kwargs):
    """
    Parallel map using joblib.
    :param pickleable_fn: Fn to map over data.
    :param data: Data to be mapped over.
    :param kwargs: Additional args for f
    :return: Mapped output.
    """
    return Parallel(n_jobs=n_jobs, verbose=verbose)(
        delayed(pickleable_fn)(d, **kwargs) for d in data
    )

# %%

mhfp_enc = MHFPEncoder()
lshforest = LSHForestHelper()


def add_to_forest(idxed_smiles):
    idx, smiles = idxed_smiles
    fp = mhfp_enc.encode(smiles)
    return fp


fps = pmap(add_to_forest, enumerate(moses_seed[:100000]))
# ~250k smiles / min

for i, fp in tqdm(enumerate(fps)):
    lshforest.add(i, fp)

lshforest.index()

pain_fps = [mhfp_enc.encode(s) for s in pain_set["smiles"]]

nns = set()
for fp in pain_fps:
    nns.update(set(lshforest.query(fp, k=200, data=fps)))
    print(len(nns))

moses_seed.iloc[list(nns)].to_csv("knn_200_from_moses_seed.csv")
# 63899

# %%
#moses_train = pd.read_csv("~/data/_moses_train.csv")
#zs = moses_seed.iloc[list(nns)].rename(columns={"smiles": "SMILES"})

#df = moses_train.append(zs)
#df["SPLIT"] = "train"
#df.to_csv("~/data/knn_1000_from_zinc_train.csv", index=False)
# Out:
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 100000 out of 100000 | elapsed: 13.4min finished
# 100000it [00:27, 3657.45it/s]
# 0
# 200
# 0
# 357
# 0
# 557
# 0
# 740
# 0
# 937
# 0
# 1124
# 0
# 1324
# 0
# 1502
# 0
# 1635
# 0
# 1742
# 0
# 1942
# 0
# 2127
# 0
# 2299
# 0
# 2498
# 0
# 2624
# 0
# 2675
# 0
# 2694
# 0
# 2716
# 0
# 2882
# 0
# 3080
# 0
# 3178
# 0
# 3292
# 0
# 3456
# 0
# 3486
# 0
# 3650
# 0
# 3761
# 0
# 3784
# 0
# 3919
# 0
# 4002
# 0
# 4154
# 0
# 4212
# 0
# 4395
# 0
# 4590
# 0
# 4661
# 0
# 4699
# 0
# 4882
# 0
# 4938
# 0
# 5096
# 0
# 5169
# 0
# 5180
# 0
# 5302
# 0
# 5382
# 0
# 5552
# 0
# 5555
# 0
# 5598
# 0
# 5608
# 0
# 5791
# 0
# 5940
# 0
# 5950
# 0
# 6060
# 0
# 6194
# 0
# 6204
# 0
# 6210
# 0
# 6295
# 0
# 6423
# 0
# 6424
# 0
# 6541
# 0
# 6740
# 0
# 6910
# 0
# 7093
# 0
# 7264
# 0
# 7355
# 0
# 7359
# 0
# 7398
# 0
# 7508
# 0
# 7512
# 0
# 7708
# 0
# 7784
# 0
# 7971
# 0
# 8129
# 0
# 8141
# 0
# 8325
# 0
# 8358
# 0
# 8360
# 0
# 8551
# 0
# 8689
# 0
# 8709
# 0
# 8789
# 0
# 8906
# 0
# 9016
# 0
# 9032
# 0
# 9221
# 0
# 9390
# 0
# 9470
# 0
# 9622
# 0
# 9638
# 0
# 9752
# 0
# 9752
# 0
# 9786
# 0
# 9808
# 0
# 9950
# 0
# 9954
# 0
# 9976
# 0
# 10048
# 0
# 10090
# 0
# 10104
# 0
# 10111
# CPU times: user 13min 38s, sys: 26.5 s, total: 14min 5s
# Wall time: 14min 5s

# %%
pain_all = pd.read_csv('knn_200_from_moses_seed.csv')
pain_all = pain_all['0']

# %% [markdown]
# # Transfer Learning

# %% [markdown]
# ## 모듈

# %%
help(moses)
# Out:
# Help on package moses:
#
# NAME
#     moses
#
# PACKAGE CONTENTS
#     aae (package)
#     baselines (package)
#     char_rnn (package)
#     dataset (package)
#     interfaces
#     latentgan (package)
#     metrics (package)
#     models_storage
#     organ (package)
#     script_utils
#     utils
#     vae (package)
#
# CLASSES
#     builtins.object
#         moses.utils.CharVocab
#         moses.utils.StringDataset
#
#     class CharVocab(builtins.object)
#      |  Methods defined here:
#      |
#      |  __init__(self, chars, ss=<class 'moses.utils.SpecialTokens'>)
#      |      Initialize self.  See help(type(self)) for accurate signature.
#      |
#      |  __len__(self)
#      |
#      |  char2id(self, char)
#      |
#      |  id2char(self, id)
#      |
#      |  ids2string(self, ids, rem_bos=True, rem_eos=True)
#      |
#      |  string2ids(self, string, add_bos=False, add_eos=False)
#      |
#      |  ----------------------------------------------------------------------
#      |  Class methods defined here:
#      |
#      |  from_data(data, *args, **kwargs) from builtins.type
#      |
#      |  ----------------------------------------------------------------------
#      |  Data descriptors defined here:
#      |
#      |  __dict__
#      |      dictionary for instance variables (if defined)
#      |
#      |  __weakref__
#      |      list of weak references to the object (if defined)
#      |
#      |  bos
#      |
#      |  eos
#      |
#      |  pad
#      |
#      |  unk
#
#     class StringDataset(builtins.object)
#      |  Methods defined here:
#      |
#      |  __getitem__(self, index)
#      |      Prepares torch tensors with a given SMILES.
#      |
#      |      Arguments:
#      |          index (int): index of SMILES in the original dataset
#      |
#      |      Returns:
#      |          A tuple (with_bos, with_eos, smiles), where
#      |          * with_bos is a torch.long tensor of SMILES tokens with
#      |              BOS (beginning of a sentence) token
#      |          * with_eos is a torch.long tensor of SMILES tokens with
#      |              EOS (end of a sentence) token
#      |          * smiles is an original SMILES from the dataset
#      |
#      |  __init__(self, vocab, data)
#      |      Creates a convenient Dataset with SMILES tokinization
#      |
#      |      Arguments:
#      |          vocab: CharVocab instance for tokenization
#      |          data (list): SMILES strings for the dataset
#      |
#      |  __len__(self)
#      |      Computes a number of objects in the dataset
#      |
#      |  default_collate(self, batch, return_data=False)
#      |      Simple collate function for SMILES dataset. Joins a
#      |      batch of objects from StringDataset into a batch
#      |
#      |      Arguments:
#      |          batch: list of objects from StringDataset
#      |          pad: padding symbol, usually equals to vocab.pad
#      |          return_data: if True, will return SMILES used in a batch
#      |
#      |      Returns:
#      |          with_bos, with_eos, lengths [, data] where
#      |          * with_bos: padded sequence with BOS in the beginning
#      |          * with_eos: padded sequence with EOS in the end
#      |          * lengths: array with SMILES lengths in the batch
#      |          * data: SMILES in the batch
#      |
#      |      Note: output batch is sorted with respect to SMILES lengths in
#      |          decreasing order, since this is a default format for torch
#      |          RNN implementations
#      |
#      |  ----------------------------------------------------------------------
#      |  Data descriptors defined here:
#      |
#      |  __dict__
#      |      dictionary for instance variables (if defined)
#      |
#      |  __weakref__
#      |      list of weak references to the object (if defined)
#
# FUNCTIONS
#     get_all_metrics(gen, k=None, n_jobs=1, device='cpu', batch_size=512, pool=None, test=None, test_scaffolds=None, ptest=None, ptest_scaffolds=None, train=None)
#         Computes all available metrics between test (scaffold test)
#         and generated sets of SMILES.
#         Parameters:
#             gen: list of generated SMILES
#             k: int or list with values for unique@k. Will calculate number of
#                 unique molecules in the first k molecules. Default [1000, 10000]
#             n_jobs: number of workers for parallel processing
#             device: 'cpu' or 'cuda:n', where n is GPU device number
#             batch_size: batch size for FCD metric
#             pool: optional multiprocessing pool to use for parallelization
#
#             test (None or list): test SMILES. If None, will load
#                 a default test set
#             test_scaffolds (None or list): scaffold test SMILES. If None, will
#                 load a default scaffold test set
#             ptest (None or dict): precalculated statistics of the test set. If
#                 None, will load default test statistics. If you specified a custom
#                 test set, default test statistics will be ignored
#             ptest_scaffolds (None or dict): precalculated statistics of the
#                 scaffold test set If None, will load default scaffold test
#                 statistics. If you specified a custom test set, default test
#                 statistics will be ignored
#             train (None or list): train SMILES. If None, will load a default
#                 train set
#         Available metrics:
#             * %valid
#             * %unique@k
#             * Frechet ChemNet Distance (FCD)
#             * Fragment similarity (Frag)
#             * Scaffold similarity (Scaf)
#             * Similarity to nearest neighbour (SNN)
#             * Internal diversity (IntDiv)
#             * Internal diversity 2: using square root of mean squared
#                 Tanimoto similarity (IntDiv2)
#             * %passes filters (Filters)
#             * Distribution difference for logP, SA, QED, weight
#             * Novelty (molecules not present in train)
#
#     get_dataset(split='train')
#         Loads MOSES dataset
#
#         Arguments:
#             split (str or list): split to load. If str, must be
#                 one of: 'train', 'test', 'test_scaffolds'. If
#                 list, will load all splits from the list.
#                 None by default---loads all splits
#
#         Returns:
#             dict with splits. Keys---split names, values---lists
#             of SMILES strings.
#
# DATA
#     __all__ = ['get_dataset', 'get_all_metrics', 'CharVocab', 'StringDatas...
#
# VERSION
#     0.3.1
#
# FILE
#     /usr/local/lib/python3.6/site-packages/moses/__init__.py

# %%
help(moses.vae)
# Out:
# Help on package moses.vae in moses:
#
# NAME
#     moses.vae
#
# PACKAGE CONTENTS
#     config
#     misc
#     model
#     trainer
#
# CLASSES
#     moses.interfaces.MosesTrainer(abc.ABC)
#         moses.vae.trainer.VAETrainer
#     torch.nn.modules.module.Module(builtins.object)
#         moses.vae.model.VAE
#
#     class VAE(torch.nn.modules.module.Module)
#      |  Base class for all neural network modules.
#      |
#      |  Your models should also subclass this class.
#      |
#      |  Modules can also contain other Modules, allowing to nest them in
#      |  a tree structure. You can assign the submodules as regular attributes::
#      |
#      |      import torch.nn as nn
#      |      import torch.nn.functional as F
#      |
#      |      class Model(nn.Module):
#      |          def __init__(self):
#      |              super(Model, self).__init__()
#      |              self.conv1 = nn.Conv2d(1, 20, 5)
#      |              self.conv2 = nn.Conv2d(20, 20, 5)
#      |
#      |          def forward(self, x):
#      |              x = F.relu(self.conv1(x))
#      |              return F.relu(self.conv2(x))
#      |
#      |  Submodules assigned in this way will be registered, and will have their
#      |  parameters converted too when you call :meth:`to`, etc.
#      |
#      |  :ivar training: Boolean represents whether this module is in training or
#      |                  evaluation mode.
#      |  :vartype training: bool
#      |
#      |  Method resolution order:
#      |      VAE
#      |      torch.nn.modules.module.Module
#      |      builtins.object
#      |
#      |  Methods defined here:
#      |
#      |  __init__(self, vocab, config)
#      |      Initializes internal Module state, shared by both nn.Module and ScriptModule.
#      |
#      |  forward(self, x)
#      |      Do the VAE forward step
#      |
#      |      :param x: list of tensors of longs, input sentence x
#      |      :return: float, kl term component of loss
#      |      :return: float, recon component of loss
#      |
#      |  forward_decoder(self, x, z)
#      |      Decoder step, emulating x ~ G(z)
#      |
#      |      :param x: list of tensors of longs, input sentence x
#      |      :param z: (n_batch, d_z) of floats, latent vector z
#      |      :return: float, recon component of loss
#      |
#      |  forward_encoder(self, x)
#      |      Encoder step, emulating z ~ E(x) = q_E(z|x)
#      |
#      |      :param x: list of tensors of longs, input sentence x
#      |      :return: (n_batch, d_z) of floats, sample of latent vector z
#      |      :return: float, kl term component of loss
#      |
#      |  sample(self, n_batch, max_len=100, z=None, temp=1.0)
#      |      Generating n_batch samples in eval mode (`z` could be
#      |      not on same device)
#      |
#      |      :param n_batch: number of sentences to generate
#      |      :param max_len: max len of samples
#      |      :param z: (n_batch, d_z) of floats, latent vector z or None
#      |      :param temp: temperature of softmax
#      |      :return: list of tensors of strings, samples sequence x
#      |
#      |  sample_z_prior(self, n_batch)
#      |      Sampling z ~ p(z) = N(0, I)
#      |
#      |      :param n_batch: number of batches
#      |      :return: (n_batch, d_z) of floats, sample of latent z
#      |
#      |  string2tensor(self, string, device='model')
#      |
#      |  tensor2string(self, tensor)
#      |
#      |  ----------------------------------------------------------------------
#      |  Data descriptors defined here:
#      |
#      |  device
#      |
#      |  ----------------------------------------------------------------------
#      |  Methods inherited from torch.nn.modules.module.Module:
#      |
#      |  __call__ = _call_impl(self, *input, **kwargs)
#      |
#      |  __delattr__(self, name)
#      |      Implement delattr(self, name).
#      |
#      |  __dir__(self)
#      |      __dir__() -> list
#      |      default dir() implementation
#      |
#      |  __getattr__(self, name:str) -> Union[torch.Tensor, _ForwardRef('Module')]
#      |
#      |  __repr__(self)
#      |      Return repr(self).
#      |
#      |  __setattr__(self, name:str, value:Union[torch.Tensor, _ForwardRef('Module')]) -> None
#      |      Implement setattr(self, name, value).
#      |
#      |  __setstate__(self, state)
#      |
#      |  add_module(self, name:str, module:Union[_ForwardRef('Module'), NoneType]) -> None
#      |      Adds a child module to the current module.
#      |
#      |      The module can be accessed as an attribute using the given name.
#      |
#      |      Args:
#      |          name (string): name of the child module. The child module can be
#      |              accessed from this module using the given name
#      |          module (Module): child module to be added to the module.
#      |
#      |  apply(self:~T, fn:Callable[[_ForwardRef('Module')], NoneType]) -> ~T
#      |      Applies ``fn`` recursively to every submodule (as returned by ``.children()``)
#      |      as well as self. Typical use includes initializing the parameters of a model
#      |      (see also :ref:`nn-init-doc`).
#      |
#      |      Args:
#      |          fn (:class:`Module` -> None): function to be applied to each submodule
#      |
#      |      Returns:
#      |          Module: self
#      |
#      |      Example::
#      |
#      |          >>> @torch.no_grad()
#      |          >>> def init_weights(m):
#      |          >>>     print(m)
#      |          >>>     if type(m) == nn.Linear:
#      |          >>>         m.weight.fill_(1.0)
#      |          >>>         print(m.weight)
#      |          >>> net = nn.Sequential(nn.Linear(2, 2), nn.Linear(2, 2))
#      |          >>> net.apply(init_weights)
#      |          Linear(in_features=2, out_features=2, bias=True)
#      |          Parameter containing:
#      |          tensor([[ 1.,  1.],
#      |                  [ 1.,  1.]])
#      |          Linear(in_features=2, out_features=2, bias=True)
#      |          Parameter containing:
#      |          tensor([[ 1.,  1.],
#      |                  [ 1.,  1.]])
#      |          Sequential(
#      |            (0): Linear(in_features=2, out_features=2, bias=True)
#      |            (1): Linear(in_features=2, out_features=2, bias=True)
#      |          )
#      |          Sequential(
#      |            (0): Linear(in_features=2, out_features=2, bias=True)
#      |            (1): Linear(in_features=2, out_features=2, bias=True)
#      |          )
#      |
#      |  bfloat16(self:~T) -> ~T
#      |      Casts all floating point parameters and buffers to ``bfloat16`` datatype.
#      |
#      |      Returns:
#      |          Module: self
#      |
#      |  buffers(self, recurse:bool=True) -> Iterator[torch.Tensor]
#      |      Returns an iterator over module buffers.
#      |
#      |      Args:
#      |          recurse (bool): if True, then yields buffers of this module
#      |              and all submodules. Otherwise, yields only buffers that
#      |              are direct members of this module.
#      |
#      |      Yields:
#      |          torch.Tensor: module buffer
#      |
#      |      Example::
#      |
#      |          >>> for buf in model.buffers():
#      |          >>>     print(type(buf), buf.size())
#      |          <class 'torch.Tensor'> (20L,)
#      |          <class 'torch.Tensor'> (20L, 1L, 5L, 5L)
#      |
#      |  children(self) -> Iterator[_ForwardRef('Module')]
#      |      Returns an iterator over immediate children modules.
#      |
#      |      Yields:
#      |          Module: a child module
#      |
#      |  cpu(self:~T) -> ~T
#      |      Moves all model parameters and buffers to the CPU.
#      |
#      |      Returns:
#      |          Module: self
#      |
#      |  cuda(self:~T, device:Union[int, torch.device, NoneType]=None) -> ~T
#      |      Moves all model parameters and buffers to the GPU.
#      |
#      |      This also makes associated parameters and buffers different objects. So
#      |      it should be called before constructing optimizer if the module will
#      |      live on GPU while being optimized.
#      |
#      |      Arguments:
#      |          device (int, optional): if specified, all parameters will be
#      |              copied to that device
#      |
#      |      Returns:
#      |          Module: self
#      |
#      |  double(self:~T) -> ~T
#      |      Casts all floating point parameters and buffers to ``double`` datatype.
#      |
#      |      Returns:
#      |          Module: self
#      |
#      |  eval(self:~T) -> ~T
#      |      Sets the module in evaluation mode.
#      |
#      |      This has any effect only on certain modules. See documentations of
#      |      particular modules for details of their behaviors in training/evaluation
#      |      mode, if they are affected, e.g. :class:`Dropout`, :class:`BatchNorm`,
#      |      etc.
#      |
#      |      This is equivalent with :meth:`self.train(False) <torch.nn.Module.train>`.
#      |
#      |      Returns:
#      |          Module: self
#      |
#      |  extra_repr(self) -> str
#      |      Set the extra representation of the module
#      |
#      |      To print customized extra information, you should re-implement
#      |      this method in your own modules. Both single-line and multi-line
#      |      strings are acceptable.
#      |
#      |  float(self:~T) -> ~T
#      |      Casts all floating point parameters and buffers to float datatype.
#      |
#      |      Returns:
#      |          Module: self
#      |
#      |  half(self:~T) -> ~T
#      |      Casts all floating point parameters and buffers to ``half`` datatype.
#      |
#      |      Returns:
#      |          Module: self
#      |
#      |  load_state_dict(self, state_dict:Dict[str, torch.Tensor], strict:bool=True)
#      |      Copies parameters and buffers from :attr:`state_dict` into
#      |      this module and its descendants. If :attr:`strict` is ``True``, then
#      |      the keys of :attr:`state_dict` must exactly match the keys returned
#      |      by this module's :meth:`~torch.nn.Module.state_dict` function.
#      |
#      |      Arguments:
#      |          state_dict (dict): a dict containing parameters and
#      |              persistent buffers.
#      |          strict (bool, optional): whether to strictly enforce that the keys
#      |              in :attr:`state_dict` match the keys returned by this module's
#      |              :meth:`~torch.nn.Module.state_dict` function. Default: ``True``
#      |
#      |      Returns:
#      |          ``NamedTuple`` with ``missing_keys`` and ``unexpected_keys`` fields:
#      |              * **missing_keys** is a list of str containing the missing keys
#      |              * **unexpected_keys** is a list of str containing the unexpected keys
#      |
#      |  modules(self) -> Iterator[_ForwardRef('Module')]
#      |      Returns an iterator over all modules in the network.
#      |
#      |      Yields:
#      |          Module: a module in the network
#      |
#      |      Note:
#      |          Duplicate modules are returned only once. In the following
#      |          example, ``l`` will be returned only once.
#      |
#      |      Example::
#      |
#      |          >>> l = nn.Linear(2, 2)
#      |          >>> net = nn.Sequential(l, l)
#      |          >>> for idx, m in enumerate(net.modules()):
#      |                  print(idx, '->', m)
#      |
#      |          0 -> Sequential(
#      |            (0): Linear(in_features=2, out_features=2, bias=True)
#      |            (1): Linear(in_features=2, out_features=2, bias=True)
#      |          )
#      |          1 -> Linear(in_features=2, out_features=2, bias=True)
#      |
#      |  named_buffers(self, prefix:str='', recurse:bool=True) -> Iterator[Tuple[str, torch.Tensor]]
#      |      Returns an iterator over module buffers, yielding both the
#      |      name of the buffer as well as the buffer itself.
#      |
#      |      Args:
#      |          prefix (str): prefix to prepend to all buffer names.
#      |          recurse (bool): if True, then yields buffers of this module
#      |              and all submodules. Otherwise, yields only buffers that
#      |              are direct members of this module.
#      |
#      |      Yields:
#      |          (string, torch.Tensor): Tuple containing the name and buffer
#      |
#      |      Example::
#      |
#      |          >>> for name, buf in self.named_buffers():
#      |          >>>    if name in ['running_var']:
#      |          >>>        print(buf.size())
#      |
#      |  named_children(self) -> Iterator[Tuple[str, _ForwardRef('Module')]]
#      |      Returns an iterator over immediate children modules, yielding both
#      |      the name of the module as well as the module itself.
#      |
#      |      Yields:
#      |          (string, Module): Tuple containing a name and child module
#      |
#      |      Example::
#      |
#      |          >>> for name, module in model.named_children():
#      |          >>>     if name in ['conv4', 'conv5']:
#      |          >>>         print(module)
#      |
#      |  named_modules(self, memo:Union[Set[_ForwardRef('Module')], NoneType]=None, prefix:str='')
#      |      Returns an iterator over all modules in the network, yielding
#      |      both the name of the module as well as the module itself.
#      |
#      |      Yields:
#      |          (string, Module): Tuple of name and module
#      |
#      |      Note:
#      |          Duplicate modules are returned only once. In the following
#      |          example, ``l`` will be returned only once.
#      |
#      |      Example::
#      |
#      |          >>> l = nn.Linear(2, 2)
#      |          >>> net = nn.Sequential(l, l)
#      |          >>> for idx, m in enumerate(net.named_modules()):
#      |                  print(idx, '->', m)
#      |
#      |          0 -> ('', Sequential(
#      |            (0): Linear(in_features=2, out_features=2, bias=True)
#      |            (1): Linear(in_features=2, out_features=2, bias=True)
#      |          ))
#      |          1 -> ('0', Linear(in_features=2, out_features=2, bias=True))
#      |
#      |  named_parameters(self, prefix:str='', recurse:bool=True) -> Iterator[Tuple[str, torch.Tensor]]
#      |      Returns an iterator over module parameters, yielding both the
#      |      name of the parameter as well as the parameter itself.
#      |
#      |      Args:
#      |          prefix (str): prefix to prepend to all parameter names.
#      |          recurse (bool): if True, then yields parameters of this module
#      |              and all submodules. Otherwise, yields only parameters that
#      |              are direct members of this module.
#      |
#      |      Yields:
#      |          (string, Parameter): Tuple containing the name and parameter
#      |
#      |      Example::
#      |
#      |          >>> for name, param in self.named_parameters():
#      |          >>>    if name in ['bias']:
#      |          >>>        print(param.size())
#      |
#      |  parameters(self, recurse:bool=True) -> Iterator[torch.nn.parameter.Parameter]
#      |      Returns an iterator over module parameters.
#      |
#      |      This is typically passed to an optimizer.
#      |
#      |      Args:
#      |          recurse (bool): if True, then yields parameters of this module
#      |              and all submodules. Otherwise, yields only parameters that
#      |              are direct members of this module.
#      |
#      |      Yields:
#      |          Parameter: module parameter
#      |
#      |      Example::
#      |
#      |          >>> for param in model.parameters():
#      |          >>>     print(type(param), param.size())
#      |          <class 'torch.Tensor'> (20L,)
#      |          <class 'torch.Tensor'> (20L, 1L, 5L, 5L)
#      |
#      |  register_backward_hook(self, hook:Callable[[_ForwardRef('Module'), Union[Tuple[torch.Tensor, ...], torch.Tensor], Union[Tuple[torch.Tensor, ...], torch.Tensor]], Union[NoneType, torch.Tensor]]) -> torch.utils.hooks.RemovableHandle
#      |      Registers a backward hook on the module.
#      |
#      |      .. warning ::
#      |
#      |          The current implementation will not have the presented behavior
#      |          for complex :class:`Module` that perform many operations.
#      |          In some failure cases, :attr:`grad_input` and :attr:`grad_output` will only
#      |          contain the gradients for a subset of the inputs and outputs.
#      |          For such :class:`Module`, you should use :func:`torch.Tensor.register_hook`
#      |          directly on a specific input or output to get the required gradients.
#      |
#      |      The hook will be called every time the gradients with respect to module
#      |      inputs are computed. The hook should have the following signature::
#      |
#      |          hook(module, grad_input, grad_output) -> Tensor or None
#      |
#      |      The :attr:`grad_input` and :attr:`grad_output` may be tuples if the
#      |      module has multiple inputs or outputs. The hook should not modify its
#      |      arguments, but it can optionally return a new gradient with respect to
#      |      input that will be used in place of :attr:`grad_input` in subsequent
#      |      computations. :attr:`grad_input` will only correspond to the inputs given
#      |      as positional arguments.
#      |
#      |      Returns:
#      |          :class:`torch.utils.hooks.RemovableHandle`:
#      |              a handle that can be used to remove the added hook by calling
#      |              ``handle.remove()``
#      |
#      |  register_buffer(self, name:str, tensor:Union[torch.Tensor, NoneType], persistent:bool=True) -> None
#      |      Adds a buffer to the module.
#      |
#      |      This is typically used to register a buffer that should not to be
#      |      considered a model parameter. For example, BatchNorm's ``running_mean``
#      |      is not a parameter, but is part of the module's state. Buffers, by
#      |      default, are persistent and will be saved alongside parameters. This
#      |      behavior can be changed by setting :attr:`persistent` to ``False``. The
#      |      only difference between a persistent buffer and a non-persistent buffer
#      |      is that the latter will not be a part of this module's
#      |      :attr:`state_dict`.
#      |
#      |      Buffers can be accessed as attributes using given names.
#      |
#      |      Args:
#      |          name (string): name of the buffer. The buffer can be accessed
#      |              from this module using the given name
#      |          tensor (Tensor): buffer to be registered.
#      |          persistent (bool): whether the buffer is part of this module's
#      |              :attr:`state_dict`.
#      |
#      |      Example::
#      |
#      |          >>> self.register_buffer('running_mean', torch.zeros(num_features))
#      |
#      |  register_forward_hook(self, hook:Callable[..., NoneType]) -> torch.utils.hooks.RemovableHandle
#      |      Registers a forward hook on the module.
#      |
#      |      The hook will be called every time after :func:`forward` has computed an output.
#      |      It should have the following signature::
#      |
#      |          hook(module, input, output) -> None or modified output
#      |
#      |      The input contains only the positional arguments given to the module.
#      |      Keyword arguments won't be passed to the hooks and only to the ``forward``.
#      |      The hook can modify the output. It can modify the input inplace but
#      |      it will not have effect on forward since this is called after
#      |      :func:`forward` is called.
#      |
#      |      Returns:
#      |          :class:`torch.utils.hooks.RemovableHandle`:
#      |              a handle that can be used to remove the added hook by calling
#      |              ``handle.remove()``
#      |
#      |  register_forward_pre_hook(self, hook:Callable[..., NoneType]) -> torch.utils.hooks.RemovableHandle
#      |      Registers a forward pre-hook on the module.
#      |
#      |      The hook will be called every time before :func:`forward` is invoked.
#      |      It should have the following signature::
#      |
#      |          hook(module, input) -> None or modified input
#      |
#      |      The input contains only the positional arguments given to the module.
#      |      Keyword arguments won't be passed to the hooks and only to the ``forward``.
#      |      The hook can modify the input. User can either return a tuple or a
#      |      single modified value in the hook. We will wrap the value into a tuple
#      |      if a single value is returned(unless that value is already a tuple).
#      |
#      |      Returns:
#      |          :class:`torch.utils.hooks.RemovableHandle`:
#      |              a handle that can be used to remove the added hook by calling
#      |              ``handle.remove()``
#      |
#      |  register_parameter(self, name:str, param:Union[torch.nn.parameter.Parameter, NoneType]) -> None
#      |      Adds a parameter to the module.
#      |
#      |      The parameter can be accessed as an attribute using given name.
#      |
#      |      Args:
#      |          name (string): name of the parameter. The parameter can be accessed
#      |              from this module using the given name
#      |          param (Parameter): parameter to be added to the module.
#      |
#      |  requires_grad_(self:~T, requires_grad:bool=True) -> ~T
#      |      Change if autograd should record operations on parameters in this
#      |      module.
#      |
#      |      This method sets the parameters' :attr:`requires_grad` attributes
#      |      in-place.
#      |
#      |      This method is helpful for freezing part of the module for finetuning
#      |      or training parts of a model individually (e.g., GAN training).
#      |
#      |      Args:
#      |          requires_grad (bool): whether autograd should record operations on
#      |                                parameters in this module. Default: ``True``.
#      |
#      |      Returns:
#      |          Module: self
#      |
#      |  share_memory(self:~T) -> ~T
#      |
#      |  state_dict(self, destination=None, prefix='', keep_vars=False)
#      |      Returns a dictionary containing a whole state of the module.
#      |
#      |      Both parameters and persistent buffers (e.g. running averages) are
#      |      included. Keys are corresponding parameter and buffer names.
#      |
#      |      Returns:
#      |          dict:
#      |              a dictionary containing a whole state of the module
#      |
#      |      Example::
#      |
#      |          >>> module.state_dict().keys()
#      |          ['bias', 'weight']
#      |
#      |  to(self, *args, **kwargs)
#      |      Moves and/or casts the parameters and buffers.
#      |
#      |      This can be called as
#      |
#      |      .. function:: to(device=None, dtype=None, non_blocking=False)
#      |
#      |      .. function:: to(dtype, non_blocking=False)
#      |
#      |      .. function:: to(tensor, non_blocking=False)
#      |
#      |      .. function:: to(memory_format=torch.channels_last)
#      |
#      |      Its signature is similar to :meth:`torch.Tensor.to`, but only accepts
#      |      floating point desired :attr:`dtype` s. In addition, this method will
#      |      only cast the floating point parameters and buffers to :attr:`dtype`
#      |      (if given). The integral parameters and buffers will be moved
#      |      :attr:`device`, if that is given, but with dtypes unchanged. When
#      |      :attr:`non_blocking` is set, it tries to convert/move asynchronously
#      |      with respect to the host if possible, e.g., moving CPU Tensors with
#      |      pinned memory to CUDA devices.
#      |
#      |      See below for examples.
#      |
#      |      .. note::
#      |          This method modifies the module in-place.
#      |
#      |      Args:
#      |          device (:class:`torch.device`): the desired device of the parameters
#      |              and buffers in this module
#      |          dtype (:class:`torch.dtype`): the desired floating point type of
#      |              the floating point parameters and buffers in this module
#      |          tensor (torch.Tensor): Tensor whose dtype and device are the desired
#      |              dtype and device for all parameters and buffers in this module
#      |          memory_format (:class:`torch.memory_format`): the desired memory
#      |              format for 4D parameters and buffers in this module (keyword
#      |              only argument)
#      |
#      |      Returns:
#      |          Module: self
#      |
#      |      Example::
#      |
#      |          >>> linear = nn.Linear(2, 2)
#      |          >>> linear.weight
#      |          Parameter containing:
#      |          tensor([[ 0.1913, -0.3420],
#      |                  [-0.5113, -0.2325]])
#      |          >>> linear.to(torch.double)
#      |          Linear(in_features=2, out_features=2, bias=True)
#      |          >>> linear.weight
#      |          Parameter containing:
#      |          tensor([[ 0.1913, -0.3420],
#      |                  [-0.5113, -0.2325]], dtype=torch.float64)
#      |          >>> gpu1 = torch.device("cuda:1")
#      |          >>> linear.to(gpu1, dtype=torch.half, non_blocking=True)
#      |          Linear(in_features=2, out_features=2, bias=True)
#      |          >>> linear.weight
#      |          Parameter containing:
#      |          tensor([[ 0.1914, -0.3420],
#      |                  [-0.5112, -0.2324]], dtype=torch.float16, device='cuda:1')
#      |          >>> cpu = torch.device("cpu")
#      |          >>> linear.to(cpu)
#      |          Linear(in_features=2, out_features=2, bias=True)
#      |          >>> linear.weight
#      |          Parameter containing:
#      |          tensor([[ 0.1914, -0.3420],
#      |                  [-0.5112, -0.2324]], dtype=torch.float16)
#      |
#      |  train(self:~T, mode:bool=True) -> ~T
#      |      Sets the module in training mode.
#      |
#      |      This has any effect only on certain modules. See documentations of
#      |      particular modules for details of their behaviors in training/evaluation
#      |      mode, if they are affected, e.g. :class:`Dropout`, :class:`BatchNorm`,
#      |      etc.
#      |
#      |      Args:
#      |          mode (bool): whether to set training mode (``True``) or evaluation
#      |                       mode (``False``). Default: ``True``.
#      |
#      |      Returns:
#      |          Module: self
#      |
#      |  type(self:~T, dst_type:Union[torch.dtype, str]) -> ~T
#      |      Casts all parameters and buffers to :attr:`dst_type`.
#      |
#      |      Arguments:
#      |          dst_type (type or string): the desired type
#      |
#      |      Returns:
#      |          Module: self
#      |
#      |  zero_grad(self, set_to_none:bool=False) -> None
#      |      Sets gradients of all model parameters to zero. See similar function
#      |      under :class:`torch.optim.Optimizer` for more context.
#      |
#      |      Arguments:
#      |          set_to_none (bool): instead of setting to zero, set the grads to None.
#      |              See :meth:`torch.optim.Optimizer.zero_grad` for details.
#      |
#      |  ----------------------------------------------------------------------
#      |  Data descriptors inherited from torch.nn.modules.module.Module:
#      |
#      |  __dict__
#      |      dictionary for instance variables (if defined)
#      |
#      |  __weakref__
#      |      list of weak references to the object (if defined)
#      |
#      |  ----------------------------------------------------------------------
#      |  Data and other attributes inherited from torch.nn.modules.module.Module:
#      |
#      |  T_destination = ~T_destination
#      |      Type variable.
#      |
#      |      Usage::
#      |
#      |        T = TypeVar('T')  # Can be anything
#      |        A = TypeVar('A', str, bytes)  # Must be str or bytes
#      |
#      |      Type variables exist primarily for the benefit of static type
#      |      checkers.  They serve as the parameters for generic types as well
#      |      as for generic function definitions.  See class Generic for more
#      |      information on generic types.  Generic functions work as follows:
#      |
#      |        def repeat(x: T, n: int) -> List[T]:
#      |            '''Return a list containing n references to x.'''
#      |            return [x]*n
#      |
#      |        def longest(x: A, y: A) -> A:
#      |            '''Return the longest of two strings.'''
#      |            return x if len(x) >= len(y) else y
#      |
#      |      The latter example's signature is essentially the overloading
#      |      of (str, str) -> str and (bytes, bytes) -> bytes.  Also note
#      |      that if the arguments are instances of some subclass of str,
#      |      the return type is still plain str.
#      |
#      |      At runtime, isinstance(x, T) and issubclass(C, T) will raise TypeError.
#      |
#      |      Type variables defined with covariant=True or contravariant=True
#      |      can be used do declare covariant or contravariant generic types.
#      |      See PEP 484 for more details. By default generic types are invariant
#      |      in all type variables.
#      |
#      |      Type variables can be introspected. e.g.:
#      |
#      |        T.__name__ == 'T'
#      |        T.__constraints__ == ()
#      |        T.__covariant__ == False
#      |        T.__contravariant__ = False
#      |        A.__constraints__ == (str, bytes)
#      |
#      |  __annotations__ = {'__call__': typing.Callable[..., typing.Any], '_ver...
#      |
#      |  dump_patches = False
#
#     class VAETrainer(moses.interfaces.MosesTrainer)
#      |  Helper class that provides a standard way to create an ABC using
#      |  inheritance.
#      |
#      |  Method resolution order:
#      |      VAETrainer
#      |      moses.interfaces.MosesTrainer
#      |      abc.ABC
#      |      builtins.object
#      |
#      |  Methods defined here:
#      |
#      |  __init__(self, config)
#      |      Initialize self.  See help(type(self)) for accurate signature.
#      |
#      |  fit(self, model, train_data, val_data=None)
#      |
#      |  get_collate_fn(self, model)
#      |
#      |  get_optim_params(self, model)
#      |
#      |  get_vocabulary(self, data)
#      |
#      |  ----------------------------------------------------------------------
#      |  Data and other attributes defined here:
#      |
#      |  __abstractmethods__ = frozenset()
#      |
#      |  ----------------------------------------------------------------------
#      |  Methods inherited from moses.interfaces.MosesTrainer:
#      |
#      |  get_collate_device(self, model)
#      |
#      |  get_dataloader(self, model, data, collate_fn=None, shuffle=True)
#      |
#      |  ----------------------------------------------------------------------
#      |  Data descriptors inherited from moses.interfaces.MosesTrainer:
#      |
#      |  n_workers
#      |
#      |  ----------------------------------------------------------------------
#      |  Data descriptors inherited from abc.ABC:
#      |
#      |  __dict__
#      |      dictionary for instance variables (if defined)
#      |
#      |  __weakref__
#      |      list of weak references to the object (if defined)
#
# FUNCTIONS
#     vae_parser = get_parser(parser=None)
#
# DATA
#     __all__ = ['vae_parser', 'VAE', 'VAETrainer']
#
# FILE
#     /usr/local/lib/python3.6/site-packages/moses/vae/__init__.py

# %% [markdown]
# ## 학습

# %%
import numpy as np
import os
if not os.path.exists(config.checkpoint_dir):
        os.mkdir(config.checkpoint_dir)
trainer.fit(vae, pain_all)
# Out:
# HBox(children=(FloatProgress(value=0.0, description='Training (epoch #0)', max=20.0, style=ProgressStyle(descr…
# HBox(children=(FloatProgress(value=0.0, description='Training (epoch #1)', max=20.0, style=ProgressStyle(descr…
# HBox(children=(FloatProgress(value=0.0, description='Training (epoch #2)', max=20.0, style=ProgressStyle(descr…
# HBox(children=(FloatProgress(value=0.0, description='Training (epoch #3)', max=20.0, style=ProgressStyle(descr…
# HBox(children=(FloatProgress(value=0.0, description='Training (epoch #4)', max=20.0, style=ProgressStyle(descr…
# HBox(children=(FloatProgress(value=0.0, description='Training (epoch #5)', max=20.0, style=ProgressStyle(descr…
# HBox(children=(FloatProgress(value=0.0, description='Training (epoch #6)', max=20.0, style=ProgressStyle(descr…
# HBox(children=(FloatProgress(value=0.0, description='Training (epoch #7)', max=20.0, style=ProgressStyle(descr…
# HBox(children=(FloatProgress(value=0.0, description='Training (epoch #8)', max=20.0, style=ProgressStyle(descr…
# HBox(children=(FloatProgress(value=0.0, description='Training (epoch #9)', max=20.0, style=ProgressStyle(descr…
# HBox(children=(FloatProgress(value=0.0, description='Training (epoch #10)', max=20.0, style=ProgressStyle(desc…
# HBox(children=(FloatProgress(value=0.0, description='Training (epoch #11)', max=20.0, style=ProgressStyle(desc…
# HBox(children=(FloatProgress(value=0.0, description='Training (epoch #12)', max=20.0, style=ProgressStyle(desc…
# HBox(children=(FloatProgress(value=0.0, description='Training (epoch #13)', max=20.0, style=ProgressStyle(desc…
# HBox(children=(FloatProgress(value=0.0, description='Training (epoch #14)', max=20.0, style=ProgressStyle(desc…
# HBox(children=(FloatProgress(value=0.0, description='Training (epoch #15)', max=20.0, style=ProgressStyle(desc…
# HBox(children=(FloatProgress(value=0.0, description='Training (epoch #16)', max=20.0, style=ProgressStyle(desc…
# HBox(children=(FloatProgress(value=0.0, description='Training (epoch #17)', max=20.0, style=ProgressStyle(desc…
# HBox(children=(FloatProgress(value=0.0, description='Training (epoch #18)', max=20.0, style=ProgressStyle(desc…
# HBox(children=(FloatProgress(value=0.0, description='Training (epoch #19)', max=20.0, style=ProgressStyle(desc…
# HBox(children=(FloatProgress(value=0.0, description='Training (epoch #20)', max=20.0, style=ProgressStyle(desc…
# HBox(children=(FloatProgress(value=0.0, description='Training (epoch #21)', max=20.0, style=ProgressStyle(desc…
# HBox(children=(FloatProgress(value=0.0, description='Training (epoch #22)', max=20.0, style=ProgressStyle(desc…
# HBox(children=(FloatProgress(value=0.0, description='Training (epoch #23)', max=20.0, style=ProgressStyle(desc…
# HBox(children=(FloatProgress(value=0.0, description='Training (epoch #24)', max=20.0, style=ProgressStyle(desc…
# HBox(children=(FloatProgress(value=0.0, description='Training (epoch #25)', max=20.0, style=ProgressStyle(desc…
# HBox(children=(FloatProgress(value=0.0, description='Training (epoch #26)', max=20.0, style=ProgressStyle(desc…
# HBox(children=(FloatProgress(value=0.0, description='Training (epoch #27)', max=20.0, style=ProgressStyle(desc…
# HBox(children=(FloatProgress(value=0.0, description='Training (epoch #28)', max=20.0, style=ProgressStyle(desc…
# HBox(children=(FloatProgress(value=0.0, description='Training (epoch #29)', max=20.0, style=ProgressStyle(desc…
# HBox(children=(FloatProgress(value=0.0, description='Training (epoch #30)', max=20.0, style=ProgressStyle(desc…
# HBox(children=(FloatProgress(value=0.0, description='Training (epoch #31)', max=20.0, style=ProgressStyle(desc…
# HBox(children=(FloatProgress(value=0.0, description='Training (epoch #32)', max=20.0, style=ProgressStyle(desc…
# HBox(children=(FloatProgress(value=0.0, description='Training (epoch #33)', max=20.0, style=ProgressStyle(desc…
# HBox(children=(FloatProgress(value=0.0, description='Training (epoch #34)', max=20.0, style=ProgressStyle(desc…
# HBox(children=(FloatProgress(value=0.0, description='Training (epoch #35)', max=20.0, style=ProgressStyle(desc…
# HBox(children=(FloatProgress(value=0.0, description='Training (epoch #36)', max=20.0, style=ProgressStyle(desc…
# HBox(children=(FloatProgress(value=0.0, description='Training (epoch #37)', max=20.0, style=ProgressStyle(desc…
# HBox(children=(FloatProgress(value=0.0, description='Training (epoch #38)', max=20.0, style=ProgressStyle(desc…
# HBox(children=(FloatProgress(value=0.0, description='Training (epoch #39)', max=20.0, style=ProgressStyle(desc…
# HBox(children=(FloatProgress(value=0.0, description='Training (epoch #40)', max=20.0, style=ProgressStyle(desc…
# HBox(children=(FloatProgress(value=0.0, description='Training (epoch #41)', max=20.0, style=ProgressStyle(desc…
# HBox(children=(FloatProgress(value=0.0, description='Training (epoch #42)', max=20.0, style=ProgressStyle(desc…
# HBox(children=(FloatProgress(value=0.0, description='Training (epoch #43)', max=20.0, style=ProgressStyle(desc…
# HBox(children=(FloatProgress(value=0.0, description='Training (epoch #44)', max=20.0, style=ProgressStyle(desc…
# HBox(children=(FloatProgress(value=0.0, description='Training (epoch #45)', max=20.0, style=ProgressStyle(desc…
# HBox(children=(FloatProgress(value=0.0, description='Training (epoch #46)', max=20.0, style=ProgressStyle(desc…
# HBox(children=(FloatProgress(value=0.0, description='Training (epoch #47)', max=20.0, style=ProgressStyle(desc…
# HBox(children=(FloatProgress(value=0.0, description='Training (epoch #48)', max=20.0, style=ProgressStyle(desc…
# HBox(children=(FloatProgress(value=0.0, description='Training (epoch #49)', max=20.0, style=ProgressStyle(desc…
# HBox(children=(FloatProgress(value=0.0, description='Training (epoch #50)', max=20.0, style=ProgressStyle(desc…
# HBox(children=(FloatProgress(value=0.0, description='Training (epoch #51)', max=20.0, style=ProgressStyle(desc…
# HBox(children=(FloatProgress(value=0.0, description='Training (epoch #52)', max=20.0, style=ProgressStyle(desc…
# HBox(children=(FloatProgress(value=0.0, description='Training (epoch #53)', max=20.0, style=ProgressStyle(desc…
# HBox(children=(FloatProgress(value=0.0, description='Training (epoch #54)', max=20.0, style=ProgressStyle(desc…
# HBox(children=(FloatProgress(value=0.0, description='Training (epoch #55)', max=20.0, style=ProgressStyle(desc…
# HBox(children=(FloatProgress(value=0.0, description='Training (epoch #56)', max=20.0, style=ProgressStyle(desc…
# HBox(children=(FloatProgress(value=0.0, description='Training (epoch #57)', max=20.0, style=ProgressStyle(desc…
# HBox(children=(FloatProgress(value=0.0, description='Training (epoch #58)', max=20.0, style=ProgressStyle(desc…
# HBox(children=(FloatProgress(value=0.0, description='Training (epoch #59)', max=20.0, style=ProgressStyle(desc…
# HBox(children=(FloatProgress(value=0.0, description='Training (epoch #60)', max=20.0, style=ProgressStyle(desc…
# HBox(children=(FloatProgress(value=0.0, description='Training (epoch #61)', max=20.0, style=ProgressStyle(desc…
# HBox(children=(FloatProgress(value=0.0, description='Training (epoch #62)', max=20.0, style=ProgressStyle(desc…
# HBox(children=(FloatProgress(value=0.0, description='Training (epoch #63)', max=20.0, style=ProgressStyle(desc…
# HBox(children=(FloatProgress(value=0.0, description='Training (epoch #64)', max=20.0, style=ProgressStyle(desc…
# HBox(children=(FloatProgress(value=0.0, description='Training (epoch #65)', max=20.0, style=ProgressStyle(desc…
# HBox(children=(FloatProgress(value=0.0, description='Training (epoch #66)', max=20.0, style=ProgressStyle(desc…
# HBox(children=(FloatProgress(value=0.0, description='Training (epoch #67)', max=20.0, style=ProgressStyle(desc…
# HBox(children=(FloatProgress(value=0.0, description='Training (epoch #68)', max=20.0, style=ProgressStyle(desc…
# HBox(children=(FloatProgress(value=0.0, description='Training (epoch #69)', max=20.0, style=ProgressStyle(desc…
# HBox(children=(FloatProgress(value=0.0, description='Training (epoch #70)', max=20.0, style=ProgressStyle(desc…
# HBox(children=(FloatProgress(value=0.0, description='Training (epoch #71)', max=20.0, style=ProgressStyle(desc…
# HBox(children=(FloatProgress(value=0.0, description='Training (epoch #72)', max=20.0, style=ProgressStyle(desc…
# HBox(children=(FloatProgress(value=0.0, description='Training (epoch #73)', max=20.0, style=ProgressStyle(desc…
# HBox(children=(FloatProgress(value=0.0, description='Training (epoch #74)', max=20.0, style=ProgressStyle(desc…
# HBox(children=(FloatProgress(value=0.0, description='Training (epoch #75)', max=20.0, style=ProgressStyle(desc…
# HBox(children=(FloatProgress(value=0.0, description='Training (epoch #76)', max=20.0, style=ProgressStyle(desc…
# HBox(children=(FloatProgress(value=0.0, description='Training (epoch #77)', max=20.0, style=ProgressStyle(desc…
# HBox(children=(FloatProgress(value=0.0, description='Training (epoch #78)', max=20.0, style=ProgressStyle(desc…
# HBox(children=(FloatProgress(value=0.0, description='Training (epoch #79)', max=20.0, style=ProgressStyle(desc…
# HBox(children=(FloatProgress(value=0.0, description='Training (epoch #80)', max=20.0, style=ProgressStyle(desc…
# HBox(children=(FloatProgress(value=0.0, description='Training (epoch #81)', max=20.0, style=ProgressStyle(desc…
# HBox(children=(FloatProgress(value=0.0, description='Training (epoch #82)', max=20.0, style=ProgressStyle(desc…
# HBox(children=(FloatProgress(value=0.0, description='Training (epoch #83)', max=20.0, style=ProgressStyle(desc…
# HBox(children=(FloatProgress(value=0.0, description='Training (epoch #84)', max=20.0, style=ProgressStyle(desc…
# HBox(children=(FloatProgress(value=0.0, description='Training (epoch #85)', max=20.0, style=ProgressStyle(desc…
# HBox(children=(FloatProgress(value=0.0, description='Training (epoch #86)', max=20.0, style=ProgressStyle(desc…
# HBox(children=(FloatProgress(value=0.0, description='Training (epoch #87)', max=20.0, style=ProgressStyle(desc…
# HBox(children=(FloatProgress(value=0.0, description='Training (epoch #88)', max=20.0, style=ProgressStyle(desc…
# HBox(children=(FloatProgress(value=0.0, description='Training (epoch #89)', max=20.0, style=ProgressStyle(desc…
# HBox(children=(FloatProgress(value=0.0, description='Training (epoch #90)', max=20.0, style=ProgressStyle(desc…
# HBox(children=(FloatProgress(value=0.0, description='Training (epoch #91)', max=20.0, style=ProgressStyle(desc…
# HBox(children=(FloatProgress(value=0.0, description='Training (epoch #92)', max=20.0, style=ProgressStyle(desc…
# HBox(children=(FloatProgress(value=0.0, description='Training (epoch #93)', max=20.0, style=ProgressStyle(desc…
# HBox(children=(FloatProgress(value=0.0, description='Training (epoch #94)', max=20.0, style=ProgressStyle(desc…
# HBox(children=(FloatProgress(value=0.0, description='Training (epoch #95)', max=20.0, style=ProgressStyle(desc…
# HBox(children=(FloatProgress(value=0.0, description='Training (epoch #96)', max=20.0, style=ProgressStyle(desc…
# HBox(children=(FloatProgress(value=0.0, description='Training (epoch #97)', max=20.0, style=ProgressStyle(desc…
# HBox(children=(FloatProgress(value=0.0, description='Training (epoch #98)', max=20.0, style=ProgressStyle(desc…
# HBox(children=(FloatProgress(value=0.0, description='Training (epoch #99)', max=20.0, style=ProgressStyle(desc…
# VAE(
#   (x_emb): Embedding(30, 30, padding_idx=28)
#   (encoder_rnn): GRU(30, 256, batch_first=True)
#   (q_mu): Linear(in_features=256, out_features=128, bias=True)
#   (q_logvar): Linear(in_features=256, out_features=128, bias=True)
#   (decoder_rnn): GRU(158, 512, num_layers=3, batch_first=True)
#   (decoder_lat): Linear(in_features=128, out_features=512, bias=True)
#   (decoder_fc): Linear(in_features=512, out_features=30, bias=True)
#   (encoder): ModuleList(
#     (0): GRU(30, 256, batch_first=True)
#     (1): Linear(in_features=256, out_features=128, bias=True)
#     (2): Linear(in_features=256, out_features=128, bias=True)
#   )
#   (decoder): ModuleList(
#     (0): GRU(158, 512, num_layers=3, batch_first=True)
#     (1): Linear(in_features=128, out_features=512, bias=True)
#     (2): Linear(in_features=512, out_features=30, bias=True)
#   )
#   (vae): ModuleList(
#     (0): Embedding(30, 30, padding_idx=28)
#     (1): ModuleList(
#       (0): GRU(30, 256, batch_first=True)
#       (1): Linear(in_features=256, out_features=128, bias=True)
#       (2): Linear(in_features=256, out_features=128, bias=True)
#     )
#     (2): ModuleList(
#       (0): GRU(158, 512, num_layers=3, batch_first=True)
#       (1): Linear(in_features=128, out_features=512, bias=True)
#       (2): Linear(in_features=512, out_features=30, bias=True)
#     )
#   )
# )

# %%
ls checkpoints/
# Out:
# vae_log.txt       vae_model_020.pt  vae_model_060.pt
# vae_model_000.pt  vae_model_040.pt  vae_model_080.pt

# %% [markdown]
# # Old model vs New model

# %% [markdown]
# ## Random Sampling

# %%
import moses.vae
old_vae = moses.vae.VAE(vocab = vocab, config=config)
new_vae = moses.vae.VAE(vocab = vocab, config=config)

# %%
old_vae.load_state_dict(torch.load("/content/drive/My Drive/save_model/save_vae/vae_model.pt"))
# Out:
# <All keys matched successfully>

# %%
new_vae.load_state_dict(torch.load("/content/checkpoints/vae_model_080.pt"))
# Out:
# <All keys matched successfully>

# %%
# %%time
old_z = old_vae.sample_z_prior(30000)

# %%
# %%time
old_sample = old_vae.sample(30000,z=old_z)
# Out:
# /usr/local/lib/python3.6/site-packages/moses/vae/model.py:217: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead. (Triggered internally at  /pytorch/aten/src/ATen/native/IndexingUtils.h:25.)
#   x[~eos_mask, i] = w[~eos_mask]
# /usr/local/lib/python3.6/site-packages/moses/vae/model.py:219: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead. (Triggered internally at  /pytorch/aten/src/ATen/native/IndexingUtils.h:25.)
#   end_pads[i_eos_mask] = i + 1

# %%
# %%time
new_z = new_vae.sample_z_prior(30000)
# Out:
# CPU times: user 46.2 ms, sys: 806 µs, total: 47 ms
# Wall time: 51 ms

# %%
# %%time
new_sample = new_vae.sample(30000, z=new_z)
# Out:
# /usr/local/lib/python3.6/site-packages/moses/vae/model.py:217: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead. (Triggered internally at  /pytorch/aten/src/ATen/native/IndexingUtils.h:25.)
#   x[~eos_mask, i] = w[~eos_mask]
# /usr/local/lib/python3.6/site-packages/moses/vae/model.py:219: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead. (Triggered internally at  /pytorch/aten/src/ATen/native/IndexingUtils.h:25.)
#   end_pads[i_eos_mask] = i + 1
# CPU times: user 6min 43s, sys: 2.43 s, total: 6min 46s
# Wall time: 6min 46s

# %% [markdown]
# ## Calculation Property

# %%
new_z[1]
# Out:
# tensor([ 0.2953, -0.1216, -0.3650, -1.8553, -0.2924,  0.5402,  0.4303, -0.9123,
#         -2.3003, -0.6236, -0.5590, -0.3226,  0.9883,  1.0912, -1.2087, -0.2893,
#         -0.0716,  1.0993, -0.5298,  0.9909, -0.7751, -0.0060,  1.0773, -1.1391,
#         -1.1645,  2.7390,  1.0436,  0.3878, -0.7031, -0.6435, -1.3316,  1.8022,
#          0.2251, -0.5804,  1.3380, -0.9784,  1.9506, -0.4654, -2.0349,  1.0436,
#          0.2736,  1.6035, -1.6231,  0.5946,  0.8022,  1.7310, -0.4215, -1.4282,
#         -1.2695, -0.4038,  0.8789,  2.3685,  0.8435, -1.2228, -1.8491,  1.4440,
#          1.7695,  0.4443,  0.4778,  0.1781,  0.2433, -0.4036,  2.5359,  0.1569,
#         -0.5267,  1.5026,  1.4986, -0.4599, -1.1372, -0.4781,  1.8794,  0.2334,
#         -1.8407,  0.7853,  0.4647, -0.7519,  0.1209, -1.8436, -0.2808, -0.4773,
#          0.0829,  1.0285,  0.5811,  0.3026,  1.1604,  1.4195,  0.9934, -1.3978,
#         -0.8648, -1.8110,  0.8404,  0.4058, -1.1999,  1.4575, -0.9490,  0.6059,
#          0.4927,  1.0143,  1.0509,  2.3315, -1.1149, -0.7008, -2.0185,  0.2755,
#         -0.0931,  1.0972, -0.2818, -0.4663, -0.8780,  0.4787, -0.9385, -0.4837,
#         -1.1999,  0.0857,  0.4607, -0.2903,  0.2741,  0.4363, -0.6279, -1.0467,
#         -1.7954,  1.9373, -0.0703, -1.9505, -0.0181, -0.0100,  1.0570,  1.0612])

# %%
new_z.shape
# Out:
# torch.Size([1000, 128])

# %%
old_z[1]
# Out:
# tensor([ 1.3375e-01,  3.8759e-01, -3.4908e-01, -1.3759e+00, -9.5676e-01,
#         -1.5140e+00,  1.1032e-01,  6.3439e-01,  5.7579e-01,  1.9008e-01,
#          3.8842e-01, -5.6209e-01, -6.2211e-02, -1.0930e+00,  6.2968e-01,
#          1.1246e+00, -3.7704e-01, -3.8308e-01, -2.9562e-01,  1.1007e+00,
#          2.5817e+00, -2.8174e-02, -4.0653e-01,  7.0562e-01,  6.5702e-01,
#         -9.4480e-01,  1.3011e-01,  4.9606e-01, -2.0539e+00, -3.0526e+00,
#         -8.3080e-01,  1.4271e+00, -1.2881e+00,  5.3224e-01,  5.8882e-01,
#         -9.6624e-01,  1.5364e+00, -3.0121e-01,  7.5140e-01,  6.6833e-01,
#          2.3725e+00, -5.9894e-01, -6.7827e-01, -3.8580e-01,  4.7388e-03,
#          3.5295e-01, -3.8097e-01,  1.1709e+00, -2.7399e-03, -7.8195e-01,
#          1.3228e+00, -1.0606e+00, -4.1963e-01,  4.2509e-01, -1.6267e-01,
#          4.7607e-01,  8.6101e-01, -7.4765e-01, -1.9518e-01, -9.5403e-01,
#          1.3087e+00,  1.9876e+00,  1.6464e-01,  1.1409e+00, -4.3670e-01,
#          1.9663e-01,  7.2327e-01,  1.0637e+00,  7.8732e-01, -1.3931e+00,
#         -1.0253e-01, -2.7376e-01,  6.4270e-01,  1.4565e+00, -1.3099e+00,
#         -2.8563e-01,  3.8926e-01, -5.3725e-01,  5.3239e-01, -1.9540e+00,
#         -1.7241e-02, -9.4186e-01,  4.0297e-01, -2.0034e+00,  2.3580e-01,
#         -3.7776e-01,  2.3013e-01,  8.5923e-01, -6.0594e-01,  4.3476e-01,
#         -1.2938e+00,  4.7032e-01, -3.5844e-01, -9.6739e-01,  3.4672e-01,
#         -7.4280e-01,  1.4236e+00, -3.9565e-03, -9.8084e-01, -1.8896e+00,
#         -1.2068e-01,  9.3163e-02,  2.5388e-01,  7.6962e-01, -2.6977e-01,
#          8.0412e-01, -1.0830e-01, -1.8138e+00, -3.1376e-02,  6.1295e-02,
#          7.4839e-01,  1.0600e+00, -8.7443e-01, -5.9964e-01, -4.6105e-02,
#          8.4576e-01, -1.6158e+00,  1.0643e+00,  7.9052e-02,  8.6996e-01,
#         -1.2150e+00,  1.9406e-01,  8.9316e-01, -2.8566e-01,  3.1728e-01,
#          1.0717e+00,  5.1637e-01,  1.3253e+00])

# %%
old_z.shape
# Out:
# torch.Size([30000, 128])

# %%
new_sample[1]
# Out:
# 'O=C(c1ccccc1)N1CCN(c2ccc(F)cc2)CC1'

# %%
old_sample[1]
# Out:
# 'COCCCN1CC2=C(C1=O)C(c1ccc(OC)cc1)NC(=O)N2'

# %%
def cal_prop(smiles_list):
  success_smiles = []
  logP_list = []
  qed = []
  sas = []
  count = 0
  z_num = []
  for smiles in smiles_list:
    mol = Chem.MolFromSmiles(smiles)
    if mol is not None:
      try:
        logp = logP(mol)
        qd = QED(mol)
        sa = SA(mol)
        success_smiles.append(smiles)
        logP_list.append(logp)
        qed.append(qd)
        sas.append(sa)
        z_num.append(count)
        #print(smiles, logp, qd, sa)
      except:
        pass
    count += 1
  return success_smiles, logP_list, qed,sas, z_num

def get_prop(smiles_list) :
  smi,l,q,s,z_num = cal_prop(smiles_list)
  df = [smi,l,q,s]
  df = pd.DataFrame(df).T
  df.columns = ['smiles','logP','QED','SAS']
  return df, z_num

# %%
# %%time
new_sample_prop, new_z_num= get_prop(new_sample)
print(new_sample_prop)
# Out:
#                                                 smiles  ...      SAS
# 0               COc1ccc(C(=O)Nc2cc(Cl)ccc2N2CCOCC2)cc1  ...  1.77164
# 1            CC(C)(C)OC(=O)N1CCN(C(=O)c2cccc(Cl)c2)CC1  ...  1.81298
# 2                  Nc1ccc(S(=O)(=O)Nc2cccc3ncccc23)cc1  ...  1.85228
# 3                Cn1nnc2c(N3CCN(c4ccc(F)cc4)CC3)ncnc21  ...  2.28327
# 4                COc1ccc(OC)c(Nc2ccc(S(C)(=O)=O)nn2)c1  ...  2.22545
# ...                                                ...  ...      ...
# 29613  CC(=O)c1c(O)c(C(C)=O)c2oc(=O)cc(-c3ccccc3)c2c1O  ...  2.51231
# 29614          COC(=O)C1=C(C)NC(=O)NC1c1ccc(OC(F)F)cc1  ...  2.70419
# 29615              COc1ccc(CCNC(=O)c2cc(C)n(C)n2)cc1OC  ...  1.98463
# 29616              CC(=O)c1c(C(C)=O)c(C)n(C2CCCCC2)c1C  ...  2.35988
# 29617      COc1cc(OC)c2c(=O)c(-c3ccc(OC)c(OC)c3)coc2c1  ...  2.15783
#
# [29618 rows x 4 columns]
# CPU times: user 1min 30s, sys: 4.78 s, total: 1min 35s
# Wall time: 1min 35s

# %%
# %%time

old_sample_prop, old_z_num= get_prop(old_sample)
print(old_sample_prop)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-c07ae7597a02> in <module>()
# ----> 1 get_ipython().run_cell_magic('time', '', '\nold_sample_prop, old_z_num= get_prop(old_sample)\nprint(old_sample_prop)')
#
# /usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py in run_cell_magic(self, magic_name, line, cell)
#    2115             magic_arg_s = self.var_expand(line, stack_depth)
#    2116             with self.builtin_trap:
# -> 2117                 result = fn(magic_arg_s, cell)
#    2118             return result
#    2119
#
# <decorator-gen-60> in time(self, line, cell, local_ns)
#
# /usr/local/lib/python3.6/dist-packages/IPython/core/magic.py in <lambda>(f, *a, **k)
#     186     # but it's overkill for just that one bit of state.
#     187     def magic_deco(arg):
# --> 188         call = lambda f, *a, **k: f(*a, **k)
#     189
#     190         if callable(arg):
#
# /usr/local/lib/python3.6/dist-packages/IPython/core/magics/execution.py in time(self, line, cell, local_ns)
#    1191         else:
#    1192             st = clock2()
# -> 1193             exec(code, glob, local_ns)
#    1194             end = clock2()
#    1195             out = None
#
# <timed exec> in <module>()
#
# NameError: name 'get_prop' is not defined

# %% [markdown]
# ## TSNE
# Old Model VS New Model

# %%
conda install tsnecuda cuda101 -c cannylab

# %%
new_z_nd = new_z.numpy()
new_Z = new_z_nd[new_z_num]
new_Z

# %%
new_Z.shape

# %%
from tsnecuda import TSNE
from sklearn.preprocessing import MinMaxScaler
new_Z_tsne = TSNE(n_components=2).fit_transform(new_Z)
new_Z_tsne = MinMaxScaler().fit_transform(new_Z_tsne)

# %%
new_df = pd.DataFrame(np.transpose((new_Z_tsne[:,0],new_Z_tsne[:,1])))
new_df.columns = ['x','y']

# %%
new_df

# %%
import matplotlib.pyplot as plt
# %config InlineBackend.figure_format = 'retina'
# %matplotlib inline
plt.rcParams["figure.figsize"] = (14,10)

# %%
prop_opt = ['logP','QED','SAS']
plt.scatter(x=new_df['x'], y=new_df['y'], c=new_sample_prop[prop_opt[2]],
            cmap= 'viridis', marker='.',
            s=20,alpha=0.5, edgecolors='none')

# %%
from tsnecuda import TSNE
from sklearn.preprocessing import MinMaxScaler
old_z = old_z.numpy()
old_z = old_z[old_z_num]

old_Z_tsne = TSNE(n_components=2).fit_transform(old_z)
old_Z_tsne = MinMaxScaler().fit_transform(old_Z_tsne)      
old_df = pd.DataFrame(np.transpose((old_Z_tsne[:,0],old_Z_tsne[:,1])))
old_df.columns = ['x','y']

# %%
plt.rcParams["figure.figsize"] = (14,10)
prop_opt = ['logP','QED','SAS']
plt.scatter(x=old_df['x'], y=old_df['y'], c=old_sample_prop[prop_opt[2]],
            cmap= 'viridis', marker='.',
            s=20,alpha=0.5, edgecolors='none')
